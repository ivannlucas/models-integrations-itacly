# %% [markdown]
# # Tuning de Hiperparámetros con Optuna — Modelo Deep Neuro-Fuzzy
#
# Notebook de búsqueda de hiperparámetros óptimos para el modelo DNF (Deep Neuro-Fuzzy) usando Optuna.
#
# **Contenido del notebook:**
# - **Librerías y setup** — Importación de dependencias y configuración de semilla / determinismo.
# - **Hiperparámetros a evaluar con Optuna** — Definición del espacio de búsqueda, ejecución del estudio y análisis de resultados.

# %% [markdown]
# # Librerías y setup

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
from numpy import dtype
import itertools
from torch.nn.utils import clip_grad_norm_
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, f1_score, precision_recall_curve, accuracy_score
import torch.optim as optim
from typing import Optional, Tuple, Dict, Any, List, Sequence
from collections import Counter, defaultdict
import copy
import os
import pandas as pd
import random
import json
import ast
import yaml
import pickle
import shutil
import optuna
import warnings
import logging

import sys
from pathlib import Path

ROOT = Path("..").resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.utils.common import seed_everything as src_seed_everything
from src.data_processing.preprocess import run_data_processing_pipeline as src_run_data_processing_pipeline
from src.training.trainer import run_train_pipeline as src_run_train_pipeline
from src.utils.logging import get_logger as src_get_logger

warnings.filterwarnings("ignore")

# %%
# ==============================================================================
# CONFIGURACION: Carga desde config.yaml + Determinismo robusto para Optuna
# ==============================================================================

logger = src_get_logger(__name__)

_CFG_PATH = "../config/config.yaml"

with open(_CFG_PATH, "r", encoding="utf-8") as _f:
    _yaml_cfg = yaml.safe_load(_f)

BASE_SEED = int(_yaml_cfg["project"]["seed"])
_DETERMINISM_CONFIGURED = False

def configure_determinism_runtime_once(seed: int) -> None:
    global _DETERMINISM_CONFIGURED
    if _DETERMINISM_CONFIGURED:
        return
    src_seed_everything(
        seed=seed,
        deterministic_strict=bool(_yaml_cfg["project"].get("deterministic_strict", True)),
        deterministic_warn_only=bool(_yaml_cfg["project"].get("deterministic_warn_only", False)),
    )
    _DETERMINISM_CONFIGURED = True

def reseed_trial(seed: int) -> None:
    os.environ["PYTHONHASHSEED"] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)

configure_determinism_runtime_once(BASE_SEED)

# %% [markdown]
# # Hiperparametros a evaluar con Optuna

# %%
# ==============================================================================
# CONFIGURACIÓN BASE DEL MODELO — sincronizada con config.yaml
# ==============================================================================

_data_cfg = _yaml_cfg["data_processing"]
_model_cfg = _yaml_cfg["model"]
_train_cfg = _yaml_cfg["training"]

model_cfg = {
    "data_processing": {
        # Ruta a los splits preprocesados (train.csv / val.csv / test.csv)
        "data_path": "../data/splits",
        "target_column": _data_cfg["target_column"],
        "id_column": _data_cfg["id_column"],
        "sequence_length": _data_cfg["sequence_length"],
        "solapamiento_beta": _data_cfg["solapamiento_beta"],
        "fuzzy_processing": copy.deepcopy(_data_cfg["fuzzy_processing"]),
    },
    "lstm": copy.deepcopy(_model_cfg["lstm"]),
    "fuzzy": copy.deepcopy(_model_cfg["fuzzy"]),
    "training_kwargs": {
        "shuffle_train": bool(_train_cfg.get("shuffle_train", False)),
        "batch_size": _train_cfg["batch_size"],
        "lr_rate": _train_cfg["lr_rate"],
        "warmup_epochs": int(_train_cfg.get("warmup_epochs", 0)),
        "weight_decay": float(_train_cfg.get("weight_decay", 1e-5)),
        "num_epochs": _train_cfg["num_epochs"],
        "patience": _train_cfg["patience"],
        "grad_clip": _train_cfg["grad_clip"],
        "scheduler": copy.deepcopy(_train_cfg["scheduler"]),
        "monitor_metric": _train_cfg["monitor_metric"],
        "dnf_loss": copy.deepcopy(_train_cfg["dnf_loss"]),
    },
}

model_cfg["data_processing"]["stats_creation"] = copy.deepcopy(
    model_cfg["data_processing"]["fuzzy_processing"]["stats_creation"]
)

print("model_cfg sincronizado con config.yaml:")
for k, v in model_cfg.items():
    if isinstance(v, dict):
        print(f"  [{k}]")
        for kk, vv in v.items():
            if not isinstance(vv, dict):
                print(f"    {kk}: {vv}")
    else:
        print(f"  {k}: {v}")
# Out:
# model_cfg sincronizado con config.yaml:
#   [data_processing]
#     data_path: ../data/splits
#     target_column: fault_name
#     id_column: cycle_id
#     sequence_length: 120
#     solapamiento_beta: 0.5
#     stats_creation: ['mean', 'std', 'slope', 'max', 'min']
#   [lstm]
#     hidden_size: 64
#     num_layers: 2
#     dropout: 0.25
#     bidirectional: False
#     embedding_dim: 32
#   [fuzzy]
#     n_mf: 5
#     n_rules: 64
#     train_membership_params: True
#     train_rule_params: True
#     temperature: 0.85
#     t_norm: product
#     normalize_rules: True
#     init_alpha: sparse
#     use_log_bias: False
#     lambda_anomaly: 0.65
#   [training_kwargs]
#     shuffle_train: False
#     batch_size: 128
#     lr_rate: 0.001
#     warmup_epochs: 20
#     weight_decay: 1e-05
#     num_epochs: 200
#     patience: 30
#     grad_clip: 1.0
#     monitor_metric: 0.65*val_anomaly_f1 + 0.25*fuzzy_f1 - 0.05*dead_rules_ratio - 0.05*alpha_entropy_mean - 0.05*rule_corr

# %%
# Base config robusta
if 'model_cfg' in globals() and isinstance(model_cfg, dict):
    tuning_base_cfg = copy.deepcopy(model_cfg)
else:
    raise RuntimeError(
        "No se encontró configuración base para tuning. Ejecuta primero la celda de configuración base."
    )


def build_trial_cfg(base_cfg, trial):
    cfg = copy.deepcopy(base_cfg)

    cfg.setdefault('data_processing', {})
    cfg.setdefault('lstm', {})
    cfg.setdefault('fuzzy', {})
    cfg.setdefault('training_kwargs', {})
    cfg['training_kwargs'].setdefault('dnf_loss', {})
    cfg['training_kwargs'].setdefault('scheduler', {})


    data_cfg = cfg['data_processing']
    lstm = cfg['lstm']
    fuzzy = cfg['fuzzy']
    train = cfg['training_kwargs']
    dnf = train['dnf_loss']
    scheduler = train['scheduler']

    # -------------------------
    # DATA
    # -------------------------
    data_cfg['sequence_length'] = trial.suggest_categorical('sequence_length', [180, 210, 240])
    data_cfg['solapamiento_beta'] = trial.suggest_categorical('solapamiento_beta', [0.0, 0.5])

    # -------------------------
    # LSTM
    # -------------------------
    lstm['hidden_size'] = trial.suggest_categorical('hidden_size', [32, 64, 128])
    lstm['num_layers'] = trial.suggest_categorical('num_layers', [1, 2])
    lstm['dropout'] = trial.suggest_float('dropout', 0.10, 0.35, step=0.05)
    lstm['bidirectional'] = trial.suggest_categorical('bidirectional', [True, False])
    lstm['embedding_dim'] = trial.suggest_categorical('embedding_dim', [32, 48, 64])

    # -------------------------
    # Fuzzy
    # -------------------------
    fuzzy['n_mf'] = trial.suggest_categorical('n_mf', [3, 4, 5])
    fuzzy['n_rules'] = trial.suggest_categorical('n_rules', [24, 48, 64])
    fuzzy['temperature'] = trial.suggest_float('temperature', 0.6, 1.2, step=0.05)
    fuzzy['t_norm'] = trial.suggest_categorical('t_norm', ['product', 'min'])
    fuzzy['normalize_rules'] = trial.suggest_categorical('normalize_rules', [True, False])
    fuzzy['init_alpha'] = trial.suggest_categorical('init_alpha', ['sparse', 'random'])
    fuzzy['lambda_anomaly'] = trial.suggest_float('lambda_anomaly', 0.7, 0.90, step=0.05)

    # -------------------------
    # Entrenamiento
    # -------------------------
    train['batch_size'] = trial.suggest_categorical('batch_size', [64, 128, 256])
    train['lr_rate'] = trial.suggest_float('lr_rate', 2.5e-4, 2.5e-3, step=2.5e-4)

    scheduler['type'] = trial.suggest_categorical(
        'scheduler_type',
        ['plateau', 'cosine_warmup', 'cosine'],
    )

    # -------------------------
    # DNF Loss
    # -------------------------
    dnf['anomaly_weight'] = trial.suggest_float('anomaly_weight', 1.7, 2.50, step=0.10)
    dnf['aux_anom_dl_weight'] = trial.suggest_float('aux_anom_dl_weight', 0.30, 0.60, step=0.05)
    dnf['aux_anom_fuzzy_weight'] = trial.suggest_float('aux_anom_fuzzy_weight', 0.75, 1.25, step=0.05)
    dnf['diversity_weight'] = trial.suggest_float('diversity_weight', 0.0, 0.02, step=0.005)
    dnf['alpha_entropy_weight'] = trial.suggest_float('alpha_entropy_weight', 0.005, 0.020, step=0.005)
    dnf['rule_structure_div_weight'] = trial.suggest_float('rule_structure_div_weight', 0.00, 0.05, step=0.01)
    dnf['rule_usage_balance_weight'] = trial.suggest_float('rule_usage_balance_weight', 0.00, 0.05, step=0.01)

    return cfg

def select_best_epoch_from_history(history):
    scores = np.asarray(history.get("monitor_score", []), dtype=float)
    if scores.size == 0:
        raise ValueError("History vacío: falta 'monitor_score'.")

    best_epoch_idx = int(np.nanargmax(scores))
    best_score = float(scores[best_epoch_idx])

    best_metrics = {
        "best_epoch": best_epoch_idx + 1,
        "score": best_score,
        "val_anomaly_f1": float(np.asarray(history["val_anomaly_f1"], dtype=float)[best_epoch_idx]),
        "val_anomaly_auc": float(np.asarray(history["val_anomaly_auc"], dtype=float)[best_epoch_idx]),
        "fuzzy_f1": float(np.asarray(history["val_fuzzy_f1"], dtype=float)[best_epoch_idx]),
        "dl_f1": float(np.asarray(history["val_dl_f1"], dtype=float)[best_epoch_idx]),
        "alpha_entropy_mean": float(np.asarray(history["val_alpha_entropy"], dtype=float)[best_epoch_idx]),
        "dead_rules": int(np.asarray(history["val_dead_rules"], dtype=float)[best_epoch_idx]),
        "rule_corr_mean": float(np.asarray(history["val_rule_corr"], dtype=float)[best_epoch_idx]),
    }
    return best_score, best_metrics


def _build_data_cfg_for_trial(cfg):
    data_cfg_global = globals().get('data_cfg')
    if isinstance(data_cfg_global, dict):
        data_cfg_local = copy.deepcopy(data_cfg_global)
    else:
        data_cfg_local = {}

    data_cfg_local.update(copy.deepcopy(cfg.get('data_processing', {})))

    # Garantiza que data_path apunte a los splits procesados
    if 'data_path' not in data_cfg_local:
        data_cfg_local['data_path'] = '../data/splits'

    if 'sequence_length' not in data_cfg_local:
        raise RuntimeError("No se pudo resolver 'sequence_length' en data_cfg para el trial.")

    # Asegura normal_tokens requerido por run_data_processing_pipeline
    if data_cfg_local.get('normal_tokens') is None:
        if '_yaml_cfg' in globals() and isinstance(_yaml_cfg, dict):
            data_cfg_local['normal_tokens'] = copy.deepcopy(
                _yaml_cfg.get('data_processing', {}).get('normal_tokens',{})
            )
        elif 'NORMAL_TOKENS' in globals() and NORMAL_TOKENS is not None:
            data_cfg_local['normal_tokens'] = sorted(list(NORMAL_TOKENS))

    if data_cfg_local.get('normal_tokens') is None or len(data_cfg_local.get('normal_tokens', [])) == 0:
        raise RuntimeError(
            "No se pudo resolver 'normal_tokens' para el trial. "
            "Verifica data_processing.normal_tokens (o data.normal_tokens) en config.yaml."
        )

    return data_cfg_local

_PREPROCESS_CACHE = {}

def _make_preprocess_cache_key(data_cfg_trial):
    stats_creation = tuple(data_cfg_trial['fuzzy_processing']['stats_creation'])
    return (
        data_cfg_trial.get('data_path'),
        data_cfg_trial.get('target_column'),
        data_cfg_trial.get('id_column'),
        int(data_cfg_trial.get('sequence_length')),
        float(data_cfg_trial.get('solapamiento_beta')),
        stats_creation,
    )

def _resolve_split_data_for_trial(cfg):
    if 'src_run_data_processing_pipeline' not in globals():
        raise RuntimeError("No se encontró src_run_data_processing_pipeline en memoria para recalcular split_data por trial.")

    data_cfg_trial = _build_data_cfg_for_trial(cfg)
    cache_key = _make_preprocess_cache_key(data_cfg_trial)

    if cache_key not in _PREPROCESS_CACHE:
        split_local, stats_local, scaler_x_local, scaler_num_local = src_run_data_processing_pipeline(data_cfg_trial)
        _PREPROCESS_CACHE[cache_key] = (split_local, stats_local, scaler_x_local, scaler_num_local)

    split_local, stats_local, scaler_x_local, scaler_num_local = _PREPROCESS_CACHE[cache_key]
    return copy.deepcopy(split_local), copy.deepcopy(stats_local), copy.deepcopy(scaler_x_local), copy.deepcopy(scaler_num_local)

TEMP_OPTUNA_DIR = "../models/artifacts/temp_optuna_trials"
TEMP_BEST_BUNDLE_DIR = os.path.join(TEMP_OPTUNA_DIR, "temp_best")


def _jsonable(obj):
    if obj is None or isinstance(obj, (str, bool, int)):
        return obj

    if isinstance(obj, float):
        return obj if np.isfinite(obj) else None

    if isinstance(obj, np.integer):
        return int(obj)

    if isinstance(obj, np.floating):
        value = float(obj)
        return value if np.isfinite(value) else None

    if isinstance(obj, np.ndarray):
        return _jsonable(obj.tolist())

    if isinstance(obj, (list, tuple)):
        return [_jsonable(v) for v in obj]

    if isinstance(obj, dict):
        return {str(k): _jsonable(v) for k, v in obj.items()}

    return str(obj)

def deep_update(dst, src):
    for key, value in src.items():
        if isinstance(value, dict) and isinstance(dst.get(key), dict):
            deep_update(dst[key], value)
        else:
            dst[key] = copy.deepcopy(value)
    return dst

def save_best_trial_bundle(
    *,
    train_out,
    trial,
    score,
    best_metrics,
    checkpoint_path,
    bundle_dir=TEMP_BEST_BUNDLE_DIR,
):
    staging_dir = f"{bundle_dir}_staging"

    if os.path.exists(staging_dir):
        shutil.rmtree(staging_dir)

    os.makedirs(staging_dir, exist_ok=True)

    history = train_out["history"]

    best_threshold = train_out.get("best_threshold", 0.5)
    best_epoch = train_out.get("best_epoch", best_metrics.get("best_epoch"))
    n_epochs_trained = len(history.get("monitor_score", []))

    meta = {
        "best_threshold": float(best_threshold),
        "best_epoch": int(best_epoch),
        "n_epochs_trained": int(n_epochs_trained),
        "trial_number": int(trial.number),
        "params": dict(trial.params),
        "score": float(score),
        "best_metrics": best_metrics,
        "checkpoint_path": checkpoint_path,
        "model_cfg": train_out.get("model_cfg"),
    }

    with open(os.path.join(staging_dir, "best_meta.json"), "w", encoding="utf-8") as f:
        json.dump(_jsonable(meta), f, indent=2, ensure_ascii=False, allow_nan=False)

    if os.path.exists(bundle_dir):
        shutil.rmtree(bundle_dir)

    shutil.move(staging_dir, bundle_dir)

    return {
        "bundle_dir": bundle_dir,
        "best_meta_path": os.path.join(bundle_dir, "best_meta.json"),
    }

_CURRENT_BEST_SCORE = -np.inf
_CURRENT_BEST_CKPT = None

def objective(trial):
    global _CURRENT_BEST_SCORE, _CURRENT_BEST_CKPT

    if optuna is None:
        raise ModuleNotFoundError("Optuna no está instalado en este kernel. Instala 'optuna' para ejecutar el tuning.")
    
    # Determinismo estricto: misma semilla + comportamiento determinista en PyTorch
    reseed_trial(BASE_SEED)

    total_trials = globals().get('N_TRIALS') 
    
    print("\n" + "=" * 100)
    print(f"INICIANDO TRIAL {trial.number + 1} de {total_trials}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ")
    print("=" * 100)

    cfg = build_trial_cfg(base_cfg=tuning_base_cfg, trial=trial)
    save_prefix = f"optuna_trial_{trial.number}"
    ckpt_path = os.path.join(TEMP_OPTUNA_DIR, f"best_{save_prefix}.pt")

    split_data_local, split_data_df_stats_local, scaler_x_local, scaler_num_local = _resolve_split_data_for_trial(cfg)

    try:
        data_cfg_model = copy.deepcopy(_yaml_cfg["data_processing"])
        trial_data = cfg["data_processing"]

        data_cfg_model["sequence_length"] = trial_data["sequence_length"]
        data_cfg_model["solapamiento_beta"] = trial_data["solapamiento_beta"]
        data_cfg_model["fuzzy_processing"] = copy.deepcopy(
            trial_data["fuzzy_processing"]
        )

        model_cfg_for_train = {
            "seed": int(_yaml_cfg.get("project", {}).get("seed", 42)),
            "data_processing": data_cfg_model,
            "lstm": copy.deepcopy(cfg["lstm"]),
            "fuzzy": copy.deepcopy(cfg["fuzzy"]),
            "training_kwargs": copy.deepcopy(cfg["training_kwargs"]),
        }
        
        train_out = src_run_train_pipeline(
            split_data=split_data_local,
            model_cfg=model_cfg_for_train,
            split_data_df_stats=split_data_df_stats_local,
            save_prefix=save_prefix,
            save_dir=TEMP_OPTUNA_DIR,
        )

        history = train_out['history']
        score, best_metrics = select_best_epoch_from_history(history)

        trial.report(score, step=int(best_metrics['best_epoch']))

        for k, v in best_metrics.items():
            trial.set_user_attr(k, v)

        trial.set_user_attr('best_threshold', float(train_out.get('best_threshold')))
        trial.set_user_attr('best_epoch', int(train_out.get('best_epoch')))
        trial.set_user_attr('n_epochs_trained', int(len(history.get('monitor_score', []))))

        if trial.should_prune():
            raise optuna.TrialPruned()

         # Si este trial mejora al mejor histórico de esta ejecución, conservar su checkpoint
        trial.set_user_attr("checkpoint_path", ckpt_path)
        if np.isfinite(score) and float(score) > _CURRENT_BEST_SCORE:
            prev_ckpt = _CURRENT_BEST_CKPT

            bundle_paths = save_best_trial_bundle(
                train_out=train_out,
                trial=trial,
                score=score,
                best_metrics=best_metrics,
                checkpoint_path=ckpt_path,
            )

            _CURRENT_BEST_SCORE = float(score)
            _CURRENT_BEST_CKPT = ckpt_path

            trial.set_user_attr("bundle_dir", bundle_paths["bundle_dir"])
            trial.set_user_attr("best_meta_path", bundle_paths["best_meta_path"])

            if prev_ckpt and prev_ckpt != ckpt_path and os.path.exists(prev_ckpt):
                try:
                    os.remove(prev_ckpt)
                except Exception:
                    pass
        return score

    except RuntimeError as exc:
        message = str(exc).lower()
        if 'out of memory' in message or ('cuda' in message and 'memory' in message):
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
            raise optuna.TrialPruned() from exc
        raise
    finally:
        
        # Borrar solo si NO es el mejor actual
        if ckpt_path != _CURRENT_BEST_CKPT and os.path.exists(ckpt_path):
            try:
                os.remove(ckpt_path)
            except Exception:
                pass

# %%
# ==============================================================================
# EJECUCIÓN DEL ESTUDIO DE OPTUNA
# ==============================================================================

N_TRIALS = 80

# Configuración del sampler y el pruner
sampler = optuna.samplers.TPESampler(
    seed=BASE_SEED,
    multivariate=True,
    group=True,
)
pruner = optuna.pruners.MedianPruner(
    n_startup_trials=8,
    n_warmup_steps=3,
    interval_steps=1,
    n_min_trials=8,
)

# Creación del estudio
study = optuna.create_study(
    direction="maximize",
    sampler=sampler,
    pruner=pruner,
    study_name="parallel_dnf_tuning",
    load_if_exists=True,
)

study.optimize(
    objective,
    n_trials=N_TRIALS,
    gc_after_trial=True,
    show_progress_bar=True,
)

# ========================================
# PROCESAMIENTO DE RESULTADOS FINALES
# ========================================

best_trial = study.best_trial
print(f"Mejor trial: {best_trial.number}")
print(f"Mejor score: {best_trial.value:.6f}")

print("\n=== Mejores hiperparámetros optimizados ===")
print(json.dumps(best_trial.params, indent=2, ensure_ascii=False))

BEST_MODEL_PATH = "../models/artifacts/best_optuna_model.pt"
OPTUNA_BEST_TRIAL_PATH = "../models/metrics/best_optuna_results.json"

BEST_META_PATH = os.path.join(TEMP_BEST_BUNDLE_DIR, "best_meta.json")

if not os.path.exists(BEST_META_PATH):
    raise FileNotFoundError(
        f"No existe el bundle del mejor trial en {BEST_META_PATH}. "
        "El estudio no puede finalizar sin reentreno porque no hay artifacts temporales guardados."
    )

with open(BEST_META_PATH, "r", encoding="utf-8") as f:
    best_meta = json.load(f)

best_cfg = copy.deepcopy(best_meta.get("model_cfg", {}))

if int(best_meta["trial_number"]) != int(best_trial.number):
    raise RuntimeError(
        f"El bundle temporal pertenece al trial {best_meta['trial_number']}, "
        f"pero study.best_trial es el trial {best_trial.number}. "
        "Revisa si reutilizaste un estudio anterior sin conservar su temp_best."
    )

os.makedirs("../models/artifacts", exist_ok=True)
os.makedirs("../models/metrics", exist_ok=True)

best_ckpt_src = best_meta["checkpoint_path"]
if not os.path.exists(best_ckpt_src):
    raise FileNotFoundError(f"No existe el checkpoint del mejor trial: {best_ckpt_src}")

ckpt_obj = torch.load(best_ckpt_src, map_location="cpu")

if isinstance(ckpt_obj, dict) and "model_state_dict" in ckpt_obj:
    checkpoint_payload = dict(ckpt_obj)
elif isinstance(ckpt_obj, dict) and "state_dict" in ckpt_obj:
    checkpoint_payload = dict(ckpt_obj)
    checkpoint_payload["model_state_dict"] = checkpoint_payload.pop("state_dict")
else:
    checkpoint_payload = {
        "model_state_dict": ckpt_obj,
    }

checkpoint_payload.update(
    {
        "model_cfg": best_cfg,
        "best_threshold": float(best_meta["best_threshold"]),
        "best_epoch": int(best_meta["best_epoch"]),
        "n_epochs_trained": int(best_meta["n_epochs_trained"]),
        "params": best_meta["params"],
    }
)

torch.save(checkpoint_payload, BEST_MODEL_PATH)


best_results = {
    "best_trial_number": int(best_trial.number),
    "best_value": float(best_trial.value),
    "best_threshold": float(best_meta["best_threshold"]),
    "best_epoch": int(best_meta["best_epoch"]),
    "n_epochs_trained": int(best_meta["n_epochs_trained"]),
    "model_path": BEST_MODEL_PATH,
    "temp_best_bundle": TEMP_BEST_BUNDLE_DIR,
    "params": best_meta["params"],
    "user_attrs": dict(best_trial.user_attrs),
}

with open(OPTUNA_BEST_TRIAL_PATH, "w", encoding="utf-8") as f:
    json.dump(_jsonable(best_results), f, indent=2, ensure_ascii=False, allow_nan=False)

print(f"\nModelo Optuna guardado en: {BEST_MODEL_PATH}")
print(f"Mejor trial guardado en: {OPTUNA_BEST_TRIAL_PATH}")

if os.path.exists(TEMP_OPTUNA_DIR):
    try:
        shutil.rmtree(TEMP_OPTUNA_DIR)
        print(f"Carpeta temporal '{TEMP_OPTUNA_DIR}' eliminada con éxito.")
    except Exception as exc:
        print(f"No se pudo eliminar la carpeta temporal de forma automática: {exc}")

trials_df = study.trials_dataframe(attrs=("number", "value", "state", "params", "user_attrs"))
if not trials_df.empty:
    trials_df = trials_df.sort_values(by="value", ascending=False)

    print("\n=== Top 10 trials ===")
    with pd.option_context('display.max_columns', None):
        print(trials_df.head(10))

print("\n=== Importancia de hiperparámetros ===")
try:
    importances = optuna.importance.get_param_importances(study)
    print(json.dumps(importances, indent=2, ensure_ascii=False))
except Exception as exc:
    print(f"No se pudo calcular importancias: {exc}")
# Out:
# [I 2026-07-09 16:30:09,763] A new study created in memory with name: parallel_dnf_tuning
#   0%|          | 0/80 [00:00<?, ?it/s]
# ====================================================================================================
# INICIANDO TRIAL 1 de 80
# ====================================================================================================
# 2026-07-09 16:30:09 - Cargando datos desde archivos CSV en ../data/splits
# 2026-07-09 16:30:13 -   Train: 1200000 muestras
# 2026-07-09 16:30:14 -   Val: 240000 muestras
# 2026-07-09 16:30:15 -   Test: 360000 muestras
# 2026-07-09 16:30:27 - ==============================
# 2026-07-09 16:30:27 - Arquitectura configurada:
# 2026-07-09 16:30:27 - ==============================
# 2026-07-09 16:30:27 - Rama DL: Input (210, 13) -> LSTM(hidden=128, layers=2, bidir=True) -> Atención -> Embedding 32 -> Head anom 1
# 2026-07-09 16:30:27 - Rama Fuzzy: Input 65 -> Membership (4 por feature) -> Reglas (48) -> Output anom 1
# 2026-07-09 16:30:27 - Mezcla tardía: lambda_anom=0.700
# 2026-07-09 16:30:27 - Total de parámetros: 599,146
# 2026-07-09 16:30:27 - - Parámetros entrenables: 599,146
# 2026-07-09 16:30:27 - - Parámetros rama fuzzy: 16,168
# 2026-07-09 16:30:27 - - Parámetros rama DL: 582,978
# 2026-07-09 16:30:27 - Dispositivo de entrenamiento: CUDA (NVIDIA GeForce RTX 4090) | torch=2.5.1+cu121 | build CUDA=12.1
# 2026-07-09 16:30:28 - Scheduler configurado: ReduceLROnPlateau | mode=plateau
# 2026-07-09 16:30:28 - ==============================
# 2026-07-09 16:30:30 - Epoch 001/200 | val_f1=0.6931 val_auc=0.9808 val_acc=0.9613 | alpha_ent=1.3713 rule_corr=0.6333 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.6916 dl_f1=0.4522 | monitor_score=0.5232 | lr=2.50e-03
# 2026-07-09 16:30:30 -   (Early stopping en espera - warmup 1/20)
# 2026-07-09 16:30:31 - Epoch 002/200 | val_f1=0.5065 val_auc=0.9691 val_acc=0.9050 | alpha_ent=1.3726 rule_corr=0.6761 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7347 dl_f1=0.1671 | monitor_score=0.4105 | lr=2.50e-03
# 2026-07-09 16:30:31 -   (Early stopping en espera - warmup 2/20)
# 2026-07-09 16:30:33 - Epoch 003/200 | val_f1=0.7451 val_auc=0.9897 val_acc=0.9675 | alpha_ent=1.3724 rule_corr=0.6847 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7551 dl_f1=0.6055 | monitor_score=0.5702 | lr=2.50e-03
# 2026-07-09 16:30:33 -   (Early stopping en espera - warmup 3/20)
# 2026-07-09 16:30:34 - Epoch 004/200 | val_f1=0.7347 val_auc=0.9912 val_acc=0.9675 | alpha_ent=1.3721 rule_corr=0.6911 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7347 dl_f1=0.4698 | monitor_score=0.5581 | lr=2.50e-03
# 2026-07-09 16:30:34 -   (Early stopping en espera - warmup 4/20)
# 2026-07-09 16:30:36 - Epoch 005/200 | val_f1=0.7692 val_auc=0.9925 val_acc=0.9738 | alpha_ent=1.3716 rule_corr=0.7210 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7500 dl_f1=0.7527 | monitor_score=0.5829 | lr=2.50e-03
# 2026-07-09 16:30:36 -   (Early stopping en espera - warmup 5/20)
# 2026-07-09 16:30:37 - Epoch 006/200 | val_f1=0.7609 val_auc=0.9936 val_acc=0.9725 | alpha_ent=1.3710 rule_corr=0.7399 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7500 dl_f1=0.7059 | monitor_score=0.5765 | lr=2.50e-03
# 2026-07-09 16:30:37 -   (Early stopping en espera - warmup 6/20)
# 2026-07-09 16:30:39 - Epoch 007/200 | val_f1=0.7609 val_auc=0.9945 val_acc=0.9725 | alpha_ent=1.3704 rule_corr=0.7702 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7423 dl_f1=0.7327 | monitor_score=0.5731 | lr=2.50e-03
# 2026-07-09 16:30:39 -   (Early stopping en espera - warmup 7/20)
# 2026-07-09 16:30:40 - Epoch 008/200 | val_f1=0.7955 val_auc=0.9947 val_acc=0.9775 | alpha_ent=1.3699 rule_corr=0.7888 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7579 dl_f1=0.8132 | monitor_score=0.5986 | lr=2.50e-03
# 2026-07-09 16:30:40 -   (Early stopping en espera - warmup 8/20)
# 2026-07-09 16:30:42 - Epoch 009/200 | val_f1=0.7333 val_auc=0.9935 val_acc=0.9700 | alpha_ent=1.3693 rule_corr=0.8102 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7500 dl_f1=0.8333 | monitor_score=0.5552 | lr=2.50e-03
# 2026-07-09 16:30:42 -   (Early stopping en espera - warmup 9/20)
# 2026-07-09 16:30:43 - Epoch 010/200 | val_f1=0.7640 val_auc=0.9943 val_acc=0.9738 | alpha_ent=1.3689 rule_corr=0.8169 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7423 dl_f1=0.8372 | monitor_score=0.5729 | lr=2.50e-03
# 2026-07-09 16:30:43 -   (Early stopping en espera - warmup 10/20)
# 2026-07-09 16:30:45 - Epoch 011/200 | val_f1=0.7500 val_auc=0.9943 val_acc=0.9725 | alpha_ent=1.3687 rule_corr=0.8178 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7423 dl_f1=0.8500 | monitor_score=0.5637 | lr=2.50e-03
# 2026-07-09 16:30:45 -   (Early stopping en espera - warmup 11/20)
# 2026-07-09 16:30:46 - Epoch 012/200 | val_f1=0.7765 val_auc=0.9940 val_acc=0.9762 | alpha_ent=1.3684 rule_corr=0.8156 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7347 dl_f1=0.8462 | monitor_score=0.5792 | lr=1.50e-03
# 2026-07-09 16:30:46 -   (Early stopping en espera - warmup 12/20)
# 2026-07-09 16:30:48 - Epoch 013/200 | val_f1=0.8000 val_auc=0.9949 val_acc=0.9775 | alpha_ent=1.3683 rule_corr=0.8143 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7292 dl_f1=0.8571 | monitor_score=0.5932 | lr=1.50e-03
# 2026-07-09 16:30:48 -   (Early stopping en espera - warmup 13/20)
# 2026-07-09 16:30:49 - Epoch 014/200 | val_f1=0.7727 val_auc=0.9944 val_acc=0.9750 | alpha_ent=1.3681 rule_corr=0.8090 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7500 dl_f1=0.8354 | monitor_score=0.5809 | lr=1.50e-03
# 2026-07-09 16:30:49 -   (Early stopping en espera - warmup 14/20)
# 2026-07-09 16:30:50 - Epoch 015/200 | val_f1=0.7816 val_auc=0.9945 val_acc=0.9762 | alpha_ent=1.3681 rule_corr=0.8079 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7500 dl_f1=0.8571 | monitor_score=0.5867 | lr=1.50e-03
# 2026-07-09 16:30:50 -   (Early stopping en espera - warmup 15/20)
# 2026-07-09 16:30:52 - Epoch 016/200 | val_f1=0.7727 val_auc=0.9949 val_acc=0.9750 | alpha_ent=1.3679 rule_corr=0.8141 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7500 dl_f1=0.8500 | monitor_score=0.5807 | lr=9.00e-04
# 2026-07-09 16:30:52 -   (Early stopping en espera - warmup 16/20)
# 2026-07-09 16:30:53 - Epoch 017/200 | val_f1=0.8132 val_auc=0.9956 val_acc=0.9788 | alpha_ent=1.3678 rule_corr=0.8117 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7500 dl_f1=0.8571 | monitor_score=0.6071 | lr=9.00e-04
# 2026-07-09 16:30:53 -   (Early stopping en espera - warmup 17/20)
# 2026-07-09 16:30:55 - Epoch 018/200 | val_f1=0.8000 val_auc=0.9955 val_acc=0.9775 | alpha_ent=1.3677 rule_corr=0.8079 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7292 dl_f1=0.8500 | monitor_score=0.5935 | lr=9.00e-04
# 2026-07-09 16:30:55 -   (Early stopping en espera - warmup 18/20)
# 2026-07-09 16:30:56 - Epoch 019/200 | val_f1=0.8172 val_auc=0.9959 val_acc=0.9788 | alpha_ent=1.3677 rule_corr=0.8058 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7292 dl_f1=0.8810 | monitor_score=0.6048 | lr=9.00e-04
# 2026-07-09 16:30:56 -   (Early stopping en espera - warmup 19/20)
# 2026-07-09 16:30:58 - Epoch 020/200 | val_f1=0.8000 val_auc=0.9959 val_acc=0.9775 | alpha_ent=1.3676 rule_corr=0.8047 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7292 dl_f1=0.8537 | monitor_score=0.5937 | lr=9.00e-04
# 2026-07-09 16:30:58 -   (Early stopping en espera - warmup 20/20)
# 2026-07-09 16:30:59 - Epoch 021/200 | val_f1=0.8132 val_auc=0.9958 val_acc=0.9788 | alpha_ent=1.3675 rule_corr=0.8003 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7292 dl_f1=0.8675 | monitor_score=0.6025 | lr=5.40e-04
# 2026-07-09 16:31:01 - Epoch 022/200 | val_f1=0.8352 val_auc=0.9961 val_acc=0.9812 | alpha_ent=1.3675 rule_corr=0.7997 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7292 dl_f1=0.8675 | monitor_score=0.6168 | lr=5.40e-04
# 2026-07-09 16:31:02 - Epoch 023/200 | val_f1=0.8222 val_auc=0.9955 val_acc=0.9800 | alpha_ent=1.3675 rule_corr=0.7986 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7292 dl_f1=0.8780 | monitor_score=0.6084 | lr=5.40e-04
# 2026-07-09 16:31:04 - Epoch 024/200 | val_f1=0.8444 val_auc=0.9955 val_acc=0.9825 | alpha_ent=1.3674 rule_corr=0.7974 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7158 dl_f1=0.8537 | monitor_score=0.6196 | lr=5.40e-04
# 2026-07-09 16:31:05 - Epoch 025/200 | val_f1=0.8315 val_auc=0.9941 val_acc=0.9812 | alpha_ent=1.3674 rule_corr=0.7955 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7292 dl_f1=0.8675 | monitor_score=0.6146 | lr=5.40e-04
# 2026-07-09 16:31:07 - Epoch 026/200 | val_f1=0.8409 val_auc=0.9943 val_acc=0.9825 | alpha_ent=1.3673 rule_corr=0.7942 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7292 dl_f1=0.8642 | monitor_score=0.6208 | lr=5.40e-04
# 2026-07-09 16:31:08 - Epoch 027/200 | val_f1=0.8372 val_auc=0.9930 val_acc=0.9825 | alpha_ent=1.3672 rule_corr=0.7940 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8642 | monitor_score=0.6165 | lr=5.40e-04
# 2026-07-09 16:31:10 - Epoch 028/200 | val_f1=0.8605 val_auc=0.9932 val_acc=0.9850 | alpha_ent=1.3672 rule_corr=0.7917 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7158 dl_f1=0.9024 | monitor_score=0.6303 | lr=5.40e-04
# 2026-07-09 16:31:11 - Epoch 029/200 | val_f1=0.8372 val_auc=0.9901 val_acc=0.9825 | alpha_ent=1.3672 rule_corr=0.7908 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7083 dl_f1=0.8889 | monitor_score=0.6134 | lr=5.40e-04
# 2026-07-09 16:31:13 - Epoch 030/200 | val_f1=0.8506 val_auc=0.9899 val_acc=0.9838 | alpha_ent=1.3671 rule_corr=0.7890 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8889 | monitor_score=0.6255 | lr=5.40e-04
# 2026-07-09 16:31:14 - Epoch 031/200 | val_f1=0.8636 val_auc=0.9905 val_acc=0.9850 | alpha_ent=1.3671 rule_corr=0.7888 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8861 | monitor_score=0.6340 | lr=5.40e-04
# 2026-07-09 16:31:16 - Epoch 032/200 | val_f1=0.8471 val_auc=0.9864 val_acc=0.9838 | alpha_ent=1.3671 rule_corr=0.7885 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8571 | monitor_score=0.6232 | lr=5.40e-04
# 2026-07-09 16:31:17 - Epoch 033/200 | val_f1=0.8675 val_auc=0.9846 val_acc=0.9862 | alpha_ent=1.3670 rule_corr=0.7876 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8571 | monitor_score=0.6365 | lr=5.40e-04
# 2026-07-09 16:31:19 - Epoch 034/200 | val_f1=0.8506 val_auc=0.9836 val_acc=0.9838 | alpha_ent=1.3670 rule_corr=0.7858 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8608 | monitor_score=0.6256 | lr=5.40e-04
# 2026-07-09 16:31:20 - Epoch 035/200 | val_f1=0.8706 val_auc=0.9833 val_acc=0.9862 | alpha_ent=1.3670 rule_corr=0.7852 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7347 dl_f1=0.8684 | monitor_score=0.6419 | lr=5.40e-04
# 2026-07-09 16:31:21 - Epoch 036/200 | val_f1=0.8636 val_auc=0.9858 val_acc=0.9850 | alpha_ent=1.3670 rule_corr=0.7819 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8861 | monitor_score=0.6343 | lr=5.40e-04
# 2026-07-09 16:31:23 - Epoch 037/200 | val_f1=0.8605 val_auc=0.9814 val_acc=0.9850 | alpha_ent=1.3670 rule_corr=0.7809 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8608 | monitor_score=0.6323 | lr=5.40e-04
# 2026-07-09 16:31:25 - Epoch 038/200 | val_f1=0.8539 val_auc=0.9855 val_acc=0.9838 | alpha_ent=1.3669 rule_corr=0.7809 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8642 | monitor_score=0.6281 | lr=5.40e-04
# 2026-07-09 16:31:26 - Epoch 039/200 | val_f1=0.8605 val_auc=0.9852 val_acc=0.9850 | alpha_ent=1.3669 rule_corr=0.7801 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8537 | monitor_score=0.6324 | lr=3.24e-04
# 2026-07-09 16:31:28 - Epoch 040/200 | val_f1=0.9176 val_auc=0.9826 val_acc=0.9912 | alpha_ent=1.3669 rule_corr=0.7809 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8500 | monitor_score=0.6695 | lr=3.24e-04
# 2026-07-09 16:31:29 - Epoch 041/200 | val_f1=0.8471 val_auc=0.9744 val_acc=0.9838 | alpha_ent=1.3669 rule_corr=0.7807 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8500 | monitor_score=0.6236 | lr=3.24e-04
# 2026-07-09 16:31:31 - Epoch 042/200 | val_f1=0.8941 val_auc=0.9853 val_acc=0.9888 | alpha_ent=1.3669 rule_corr=0.7805 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8750 | monitor_score=0.6542 | lr=3.24e-04
# 2026-07-09 16:31:32 - Epoch 043/200 | val_f1=0.8675 val_auc=0.9852 val_acc=0.9862 | alpha_ent=1.3669 rule_corr=0.7812 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8395 | monitor_score=0.6369 | lr=3.24e-04
# 2026-07-09 16:31:34 - Epoch 044/200 | val_f1=0.8810 val_auc=0.9858 val_acc=0.9875 | alpha_ent=1.3668 rule_corr=0.7820 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8750 | monitor_score=0.6456 | lr=1.94e-04
# 2026-07-09 16:31:35 - Epoch 045/200 | val_f1=0.8675 val_auc=0.9864 val_acc=0.9862 | alpha_ent=1.3668 rule_corr=0.7823 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8537 | monitor_score=0.6368 | lr=1.94e-04
# 2026-07-09 16:31:37 - Epoch 046/200 | val_f1=0.8571 val_auc=0.9749 val_acc=0.9850 | alpha_ent=1.3668 rule_corr=0.7820 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8642 | monitor_score=0.6301 | lr=1.94e-04
# 2026-07-09 16:31:38 - Epoch 047/200 | val_f1=0.8537 val_auc=0.9864 val_acc=0.9850 | alpha_ent=1.3668 rule_corr=0.7820 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8642 | monitor_score=0.6279 | lr=1.94e-04
# 2026-07-09 16:31:39 - Epoch 048/200 | val_f1=0.8571 val_auc=0.9769 val_acc=0.9850 | alpha_ent=1.3668 rule_corr=0.7818 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8537 | monitor_score=0.6301 | lr=1.17e-04
# 2026-07-09 16:31:41 - Epoch 049/200 | val_f1=0.8675 val_auc=0.9853 val_acc=0.9862 | alpha_ent=1.3668 rule_corr=0.7819 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8500 | monitor_score=0.6368 | lr=1.17e-04
# 2026-07-09 16:31:42 - Epoch 050/200 | val_f1=0.8642 val_auc=0.9842 val_acc=0.9862 | alpha_ent=1.3668 rule_corr=0.7822 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8250 | monitor_score=0.6347 | lr=1.17e-04
# 2026-07-09 16:31:44 - Epoch 051/200 | val_f1=0.8780 val_auc=0.9739 val_acc=0.9875 | alpha_ent=1.3668 rule_corr=0.7822 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8354 | monitor_score=0.6437 | lr=1.17e-04
# 2026-07-09 16:31:45 - Epoch 052/200 | val_f1=0.8675 val_auc=0.9694 val_acc=0.9862 | alpha_ent=1.3668 rule_corr=0.7824 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8608 | monitor_score=0.6368 | lr=7.00e-05
# 2026-07-09 16:31:47 - Epoch 053/200 | val_f1=0.8675 val_auc=0.9727 val_acc=0.9862 | alpha_ent=1.3668 rule_corr=0.7824 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8500 | monitor_score=0.6368 | lr=7.00e-05
# 2026-07-09 16:31:48 - Epoch 054/200 | val_f1=0.8537 val_auc=0.9746 val_acc=0.9850 | alpha_ent=1.3669 rule_corr=0.7825 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8354 | monitor_score=0.6278 | lr=7.00e-05
# 2026-07-09 16:31:50 - Epoch 055/200 | val_f1=0.8537 val_auc=0.9779 val_acc=0.9850 | alpha_ent=1.3669 rule_corr=0.7825 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8354 | monitor_score=0.6278 | lr=7.00e-05
# 2026-07-09 16:31:51 - Epoch 056/200 | val_f1=0.8537 val_auc=0.9741 val_acc=0.9850 | alpha_ent=1.3669 rule_corr=0.7825 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8354 | monitor_score=0.6278 | lr=5.00e-05
# 2026-07-09 16:31:53 - Epoch 057/200 | val_f1=0.8537 val_auc=0.9742 val_acc=0.9850 | alpha_ent=1.3669 rule_corr=0.7825 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8354 | monitor_score=0.6278 | lr=5.00e-05
# 2026-07-09 16:31:54 - Epoch 058/200 | val_f1=0.8537 val_auc=0.9727 val_acc=0.9850 | alpha_ent=1.3669 rule_corr=0.7826 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8354 | monitor_score=0.6278 | lr=5.00e-05
# 2026-07-09 16:31:55 - Epoch 059/200 | val_f1=0.8395 val_auc=0.9737 val_acc=0.9838 | alpha_ent=1.3669 rule_corr=0.7825 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8354 | monitor_score=0.6186 | lr=5.00e-05
# 2026-07-09 16:31:57 - Epoch 060/200 | val_f1=0.8395 val_auc=0.9743 val_acc=0.9838 | alpha_ent=1.3669 rule_corr=0.7826 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8354 | monitor_score=0.6186 | lr=5.00e-05
# 2026-07-09 16:31:58 - Epoch 061/200 | val_f1=0.8395 val_auc=0.9741 val_acc=0.9838 | alpha_ent=1.3669 rule_corr=0.7829 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8354 | monitor_score=0.6186 | lr=5.00e-05
# 2026-07-09 16:32:00 - Epoch 062/200 | val_f1=0.8395 val_auc=0.9770 val_acc=0.9838 | alpha_ent=1.3669 rule_corr=0.7828 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8354 | monitor_score=0.6186 | lr=5.00e-05
# 2026-07-09 16:32:01 - Epoch 063/200 | val_f1=0.8395 val_auc=0.9657 val_acc=0.9838 | alpha_ent=1.3669 rule_corr=0.7829 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8354 | monitor_score=0.6186 | lr=5.00e-05
# 2026-07-09 16:32:03 - Epoch 064/200 | val_f1=0.8395 val_auc=0.9713 val_acc=0.9838 | alpha_ent=1.3669 rule_corr=0.7830 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8354 | monitor_score=0.6186 | lr=5.00e-05
# 2026-07-09 16:32:04 - Epoch 065/200 | val_f1=0.8395 val_auc=0.9752 val_acc=0.9838 | alpha_ent=1.3669 rule_corr=0.7830 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8354 | monitor_score=0.6186 | lr=5.00e-05
# 2026-07-09 16:32:06 - Epoch 066/200 | val_f1=0.8395 val_auc=0.9759 val_acc=0.9838 | alpha_ent=1.3669 rule_corr=0.7831 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8354 | monitor_score=0.6186 | lr=5.00e-05
# 2026-07-09 16:32:07 - Epoch 067/200 | val_f1=0.8395 val_auc=0.9796 val_acc=0.9838 | alpha_ent=1.3669 rule_corr=0.7834 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8500 | monitor_score=0.6186 | lr=5.00e-05
# 2026-07-09 16:32:09 - Epoch 068/200 | val_f1=0.8395 val_auc=0.9766 val_acc=0.9838 | alpha_ent=1.3669 rule_corr=0.7834 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8500 | monitor_score=0.6186 | lr=5.00e-05
# 2026-07-09 16:32:10 - Epoch 069/200 | val_f1=0.8395 val_auc=0.9751 val_acc=0.9838 | alpha_ent=1.3669 rule_corr=0.7833 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8354 | monitor_score=0.6186 | lr=5.00e-05
# 2026-07-09 16:32:11 - Epoch 070/200 | val_f1=0.8395 val_auc=0.9748 val_acc=0.9838 | alpha_ent=1.3669 rule_corr=0.7831 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.7216 dl_f1=0.8354 | monitor_score=0.6186 | lr=5.00e-05
# 2026-07-09 16:32:11 - Early stopping en epoch 70 (patience=30).
# [I 2026-07-09 16:32:12,243] Trial 0 finished with value: 0.6694898527803642 and parameters: {'sequence_length': 210, 'solapamiento_beta': 0.0, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'bidirectional': True, 'embedding_dim': 32, 'n_mf': 4, 'n_rules': 48, 'temperature': 0.75, 't_norm': 'min', 'normalize_rules': True, 'init_alpha': 'random', 'lambda_anomaly': 0.7, 'batch_size': 64, 'lr_rate': 0.0025, 'scheduler_type': 'plateau', 'anomaly_weight': 1.7, 'aux_anom_dl_weight': 0.5, 'aux_anom_fuzzy_weight': 0.95, 'diversity_weight': 0.0, 'alpha_entropy_weight': 0.01, 'rule_structure_div_weight': 0.0, 'rule_usage_balance_weight': 0.05}. Best is trial 0 with value: 0.6694898527803642.
#
# ====================================================================================================
# INICIANDO TRIAL 2 de 80
# ====================================================================================================
# 2026-07-09 16:32:12 - Cargando datos desde archivos CSV en ../data/splits
# 2026-07-09 16:32:16 -   Train: 1200000 muestras
# 2026-07-09 16:32:17 -   Val: 240000 muestras
# 2026-07-09 16:32:18 -   Test: 360000 muestras
# 2026-07-09 16:32:37 - ==============================
# 2026-07-09 16:32:37 - Arquitectura configurada:
# 2026-07-09 16:32:37 - ==============================
# 2026-07-09 16:32:37 - Rama DL: Input (210, 13) -> LSTM(hidden=64, layers=1, bidir=True) -> Atención -> Embedding 64 -> Head anom 1
# 2026-07-09 16:32:37 - Rama Fuzzy: Input 65 -> Membership (5 por feature) -> Reglas (64) -> Output anom 1
# 2026-07-09 16:32:37 - Mezcla tardía: lambda_anom=0.900
# 2026-07-09 16:32:37 - Total de parámetros: 82,764
# 2026-07-09 16:32:37 - - Parámetros entrenables: 82,764
# 2026-07-09 16:32:37 - - Parámetros rama fuzzy: 25,674
# 2026-07-09 16:32:37 - - Parámetros rama DL: 57,090
# 2026-07-09 16:32:37 - Dispositivo de entrenamiento: CUDA (NVIDIA GeForce RTX 4090) | torch=2.5.1+cu121 | build CUDA=12.1
# 2026-07-09 16:32:37 - Scheduler configurado: CosineAnnealingLR | mode=epoch
# 2026-07-09 16:32:37 - ==============================
# 2026-07-09 16:32:38 - Epoch 001/200 | val_f1=0.1097 val_auc=0.5681 val_acc=0.4419 | alpha_ent=0.0162 rule_corr=0.0209 dead_rules=40 dead_rules_ratio=0.6250 | fuzzy_f1=0.1102 dl_f1=0.1364 | monitor_score=0.0657 | lr=2.50e-04
# 2026-07-09 16:32:38 -   (Early stopping en espera - warmup 1/20)
# 2026-07-09 16:32:38 - Epoch 002/200 | val_f1=0.1525 val_auc=0.6670 val_acc=0.6319 | alpha_ent=0.0164 rule_corr=0.0226 dead_rules=38 dead_rules_ratio=0.5938 | fuzzy_f1=0.1570 dl_f1=0.1609 | monitor_score=0.1068 | lr=2.50e-04
# 2026-07-09 16:32:38 -   (Early stopping en espera - warmup 2/20)
# 2026-07-09 16:32:39 - Epoch 003/200 | val_f1=0.2180 val_auc=0.7728 val_acc=0.7175 | alpha_ent=0.0165 rule_corr=0.0237 dead_rules=38 dead_rules_ratio=0.5938 | fuzzy_f1=0.1910 dl_f1=0.3764 | monitor_score=0.1577 | lr=2.50e-04
# 2026-07-09 16:32:39 -   (Early stopping en espera - warmup 3/20)
# 2026-07-09 16:32:40 - Epoch 004/200 | val_f1=0.2827 val_auc=0.8300 val_acc=0.7875 | alpha_ent=0.0167 rule_corr=0.0240 dead_rules=38 dead_rules_ratio=0.5938 | fuzzy_f1=0.2146 dl_f1=0.4817 | monitor_score=0.2057 | lr=2.50e-04
# 2026-07-09 16:32:40 -   (Early stopping en espera - warmup 4/20)
# 2026-07-09 16:32:41 - Epoch 005/200 | val_f1=0.3066 val_auc=0.8533 val_acc=0.8106 | alpha_ent=0.0168 rule_corr=0.0243 dead_rules=38 dead_rules_ratio=0.5938 | fuzzy_f1=0.2458 dl_f1=0.5628 | monitor_score=0.2290 | lr=2.50e-04
# 2026-07-09 16:32:41 -   (Early stopping en espera - warmup 5/20)
# 2026-07-09 16:32:42 - Epoch 006/200 | val_f1=0.3416 val_auc=0.8675 val_acc=0.8337 | alpha_ent=0.0170 rule_corr=0.0245 dead_rules=37 dead_rules_ratio=0.5781 | fuzzy_f1=0.2658 dl_f1=0.5700 | monitor_score=0.2575 | lr=2.49e-04
# 2026-07-09 16:32:42 -   (Early stopping en espera - warmup 6/20)
# 2026-07-09 16:32:43 - Epoch 007/200 | val_f1=0.3722 val_auc=0.8746 val_acc=0.8588 | alpha_ent=0.0171 rule_corr=0.0250 dead_rules=37 dead_rules_ratio=0.5781 | fuzzy_f1=0.2837 dl_f1=0.6061 | monitor_score=0.2818 | lr=2.49e-04
# 2026-07-09 16:32:43 -   (Early stopping en espera - warmup 7/20)
# 2026-07-09 16:32:43 - Epoch 008/200 | val_f1=0.4083 val_auc=0.8833 val_acc=0.8750 | alpha_ent=0.0173 rule_corr=0.0266 dead_rules=36 dead_rules_ratio=0.5625 | fuzzy_f1=0.3003 dl_f1=0.5756 | monitor_score=0.3101 | lr=2.49e-04
# 2026-07-09 16:32:43 -   (Early stopping en espera - warmup 8/20)
# 2026-07-09 16:32:44 - Epoch 009/200 | val_f1=0.4416 val_auc=0.8964 val_acc=0.8894 | alpha_ent=0.0174 rule_corr=0.0275 dead_rules=36 dead_rules_ratio=0.5625 | fuzzy_f1=0.3217 dl_f1=0.4723 | monitor_score=0.3371 | lr=2.49e-04
# 2026-07-09 16:32:44 -   (Early stopping en espera - warmup 9/20)
# 2026-07-09 16:32:45 - Epoch 010/200 | val_f1=0.4832 val_auc=0.9042 val_acc=0.9038 | alpha_ent=0.0176 rule_corr=0.0279 dead_rules=36 dead_rules_ratio=0.5625 | fuzzy_f1=0.3370 dl_f1=0.4693 | monitor_score=0.3680 | lr=2.49e-04
# 2026-07-09 16:32:45 -   (Early stopping en espera - warmup 10/20)
# 2026-07-09 16:32:46 - Epoch 011/200 | val_f1=0.5055 val_auc=0.9062 val_acc=0.9156 | alpha_ent=0.0177 rule_corr=0.0282 dead_rules=35 dead_rules_ratio=0.5469 | fuzzy_f1=0.3410 dl_f1=0.6078 | monitor_score=0.3842 | lr=2.48e-04
# 2026-07-09 16:32:46 -   (Early stopping en espera - warmup 11/20)
# 2026-07-09 16:32:47 - Epoch 012/200 | val_f1=0.5147 val_auc=0.9137 val_acc=0.9175 | alpha_ent=0.0179 rule_corr=0.0286 dead_rules=34 dead_rules_ratio=0.5312 | fuzzy_f1=0.3591 dl_f1=0.6238 | monitor_score=0.3955 | lr=2.48e-04
# 2026-07-09 16:32:47 -   (Early stopping en espera - warmup 12/20)
# 2026-07-09 16:32:48 - Epoch 013/200 | val_f1=0.5448 val_auc=0.9177 val_acc=0.9237 | alpha_ent=0.0180 rule_corr=0.0290 dead_rules=34 dead_rules_ratio=0.5312 | fuzzy_f1=0.3684 dl_f1=0.6269 | monitor_score=0.4173 | lr=2.47e-04
# 2026-07-09 16:32:48 -   (Early stopping en espera - warmup 13/20)
# 2026-07-09 16:32:49 - Epoch 014/200 | val_f1=0.5573 val_auc=0.9219 val_acc=0.9275 | alpha_ent=0.0182 rule_corr=0.0297 dead_rules=34 dead_rules_ratio=0.5312 | fuzzy_f1=0.3904 dl_f1=0.6495 | monitor_score=0.4309 | lr=2.47e-04
# 2026-07-09 16:32:49 -   (Early stopping en espera - warmup 14/20)
# 2026-07-09 16:32:49 - Epoch 015/200 | val_f1=0.5682 val_auc=0.9267 val_acc=0.9287 | alpha_ent=0.0184 rule_corr=0.0303 dead_rules=33 dead_rules_ratio=0.5156 | fuzzy_f1=0.3945 dl_f1=0.5385 | monitor_score=0.4397 | lr=2.47e-04
# 2026-07-09 16:32:49 -   (Early stopping en espera - warmup 15/20)
# 2026-07-09 16:32:50 - Epoch 016/200 | val_f1=0.5736 val_auc=0.9305 val_acc=0.9313 | alpha_ent=0.0185 rule_corr=0.0308 dead_rules=33 dead_rules_ratio=0.5156 | fuzzy_f1=0.4028 dl_f1=0.6176 | monitor_score=0.4453 | lr=2.46e-04
# 2026-07-09 16:32:50 -   (Early stopping en espera - warmup 16/20)
# 2026-07-09 16:32:51 - Epoch 017/200 | val_f1=0.4551 val_auc=0.9246 val_acc=0.8862 | alpha_ent=0.0187 rule_corr=0.0313 dead_rules=33 dead_rules_ratio=0.5156 | fuzzy_f1=0.3957 dl_f1=0.3963 | monitor_score=0.3664 | lr=2.46e-04
# 2026-07-09 16:32:51 -   (Early stopping en espera - warmup 17/20)
# 2026-07-09 16:32:52 - Epoch 018/200 | val_f1=0.5827 val_auc=0.9340 val_acc=0.9337 | alpha_ent=0.0189 rule_corr=0.0318 dead_rules=33 dead_rules_ratio=0.5156 | fuzzy_f1=0.4059 dl_f1=0.6332 | monitor_score=0.4519 | lr=2.45e-04
# 2026-07-09 16:32:52 -   (Early stopping en espera - warmup 18/20)
# 2026-07-09 16:32:53 - Epoch 019/200 | val_f1=0.6213 val_auc=0.9343 val_acc=0.9444 | alpha_ent=0.0190 rule_corr=0.0322 dead_rules=33 dead_rules_ratio=0.5156 | fuzzy_f1=0.4045 dl_f1=0.6813 | monitor_score=0.4766 | lr=2.45e-04
# 2026-07-09 16:32:53 -   (Early stopping en espera - warmup 19/20)
# 2026-07-09 16:32:54 - Epoch 020/200 | val_f1=0.6239 val_auc=0.9374 val_acc=0.9450 | alpha_ent=0.0192 rule_corr=0.0327 dead_rules=33 dead_rules_ratio=0.5156 | fuzzy_f1=0.4154 dl_f1=0.6703 | monitor_score=0.4810 | lr=2.44e-04
# 2026-07-09 16:32:54 -   (Early stopping en espera - warmup 20/20)
# 2026-07-09 16:32:55 - Epoch 021/200 | val_f1=0.6407 val_auc=0.9432 val_acc=0.9481 | alpha_ent=0.0194 rule_corr=0.0331 dead_rules=33 dead_rules_ratio=0.5156 | fuzzy_f1=0.4170 dl_f1=0.6562 | monitor_score=0.4923 | lr=2.44e-04
# 2026-07-09 16:32:55 - Epoch 022/200 | val_f1=0.6522 val_auc=0.9450 val_acc=0.9500 | alpha_ent=0.0195 rule_corr=0.0333 dead_rules=34 dead_rules_ratio=0.5312 | fuzzy_f1=0.4308 dl_f1=0.6598 | monitor_score=0.5024 | lr=2.43e-04
# 2026-07-09 16:32:56 - Epoch 023/200 | val_f1=0.6524 val_auc=0.9452 val_acc=0.9494 | alpha_ent=0.0197 rule_corr=0.0336 dead_rules=33 dead_rules_ratio=0.5156 | fuzzy_f1=0.4297 dl_f1=0.6095 | monitor_score=0.5030 | lr=2.42e-04
# 2026-07-09 16:32:57 - Epoch 024/200 | val_f1=0.6494 val_auc=0.9447 val_acc=0.9494 | alpha_ent=0.0199 rule_corr=0.0338 dead_rules=33 dead_rules_ratio=0.5156 | fuzzy_f1=0.4314 dl_f1=0.6701 | monitor_score=0.5015 | lr=2.42e-04
# 2026-07-09 16:32:58 - Epoch 025/200 | val_f1=0.6637 val_auc=0.9474 val_acc=0.9525 | alpha_ent=0.0200 rule_corr=0.0340 dead_rules=33 dead_rules_ratio=0.5156 | fuzzy_f1=0.4358 dl_f1=0.7158 | monitor_score=0.5119 | lr=2.41e-04
# 2026-07-09 16:32:59 - Epoch 026/200 | val_f1=0.6463 val_auc=0.9477 val_acc=0.9494 | alpha_ent=0.0202 rule_corr=0.0342 dead_rules=33 dead_rules_ratio=0.5156 | fuzzy_f1=0.4394 dl_f1=0.7047 | monitor_score=0.5014 | lr=2.40e-04
# 2026-07-09 16:33:00 - Epoch 027/200 | val_f1=0.6444 val_auc=0.9486 val_acc=0.9469 | alpha_ent=0.0204 rule_corr=0.0342 dead_rules=33 dead_rules_ratio=0.5156 | fuzzy_f1=0.4514 dl_f1=0.6863 | monitor_score=0.5032 | lr=2.39e-04
# 2026-07-09 16:33:01 - Epoch 028/200 | val_f1=0.6498 val_auc=0.9480 val_acc=0.9481 | alpha_ent=0.0206 rule_corr=0.0344 dead_rules=33 dead_rules_ratio=0.5156 | fuzzy_f1=0.4567 dl_f1=0.7065 | monitor_score=0.5080 | lr=2.39e-04
# 2026-07-09 16:33:01 - Epoch 029/200 | val_f1=0.6580 val_auc=0.9496 val_acc=0.9506 | alpha_ent=0.0208 rule_corr=0.0345 dead_rules=34 dead_rules_ratio=0.5312 | fuzzy_f1=0.4514 dl_f1=0.7172 | monitor_score=0.5112 | lr=2.38e-04
# 2026-07-09 16:33:02 - Epoch 030/200 | val_f1=0.6667 val_auc=0.9509 val_acc=0.9525 | alpha_ent=0.0209 rule_corr=0.0345 dead_rules=34 dead_rules_ratio=0.5312 | fuzzy_f1=0.4549 dl_f1=0.7435 | monitor_score=0.5177 | lr=2.37e-04
# 2026-07-09 16:33:03 - Epoch 031/200 | val_f1=0.6580 val_auc=0.9528 val_acc=0.9506 | alpha_ent=0.0211 rule_corr=0.0345 dead_rules=33 dead_rules_ratio=0.5156 | fuzzy_f1=0.4585 dl_f1=0.7461 | monitor_score=0.5138 | lr=2.36e-04
# 2026-07-09 16:33:04 - Epoch 032/200 | val_f1=0.6494 val_auc=0.9531 val_acc=0.9494 | alpha_ent=0.0213 rule_corr=0.0346 dead_rules=32 dead_rules_ratio=0.5000 | fuzzy_f1=0.4706 dl_f1=0.7358 | monitor_score=0.5119 | lr=2.35e-04
# 2026-07-09 16:33:05 - Epoch 033/200 | val_f1=0.6638 val_auc=0.9561 val_acc=0.9513 | alpha_ent=0.0215 rule_corr=0.0346 dead_rules=32 dead_rules_ratio=0.5000 | fuzzy_f1=0.4706 dl_f1=0.7539 | monitor_score=0.5213 | lr=2.34e-04
# 2026-07-09 16:33:05 - Epoch 034/200 | val_f1=0.6638 val_auc=0.9526 val_acc=0.9519 | alpha_ent=0.0217 rule_corr=0.0347 dead_rules=32 dead_rules_ratio=0.5000 | fuzzy_f1=0.4777 dl_f1=0.7872 | monitor_score=0.5231 | lr=2.33e-04
# 2026-07-09 16:33:06 - Epoch 035/200 | val_f1=0.6818 val_auc=0.9510 val_acc=0.9563 | alpha_ent=0.0218 rule_corr=0.0345 dead_rules=32 dead_rules_ratio=0.5000 | fuzzy_f1=0.4876 dl_f1=0.7784 | monitor_score=0.5373 | lr=2.32e-04
# 2026-07-09 16:33:07 - Epoch 036/200 | val_f1=0.6609 val_auc=0.9559 val_acc=0.9513 | alpha_ent=0.0220 rule_corr=0.0346 dead_rules=32 dead_rules_ratio=0.5000 | fuzzy_f1=0.4819 dl_f1=0.7817 | monitor_score=0.5222 | lr=2.31e-04
# 2026-07-09 16:33:08 - Epoch 037/200 | val_f1=0.6842 val_auc=0.9555 val_acc=0.9550 | alpha_ent=0.0222 rule_corr=0.0346 dead_rules=31 dead_rules_ratio=0.4844 | fuzzy_f1=0.4960 dl_f1=0.7914 | monitor_score=0.5417 | lr=2.30e-04
# 2026-07-09 16:33:09 - Epoch 038/200 | val_f1=0.6726 val_auc=0.9515 val_acc=0.9537 | alpha_ent=0.0224 rule_corr=0.0346 dead_rules=32 dead_rules_ratio=0.5000 | fuzzy_f1=0.5020 dl_f1=0.7914 | monitor_score=0.5348 | lr=2.29e-04
# 2026-07-09 16:33:10 - Epoch 039/200 | val_f1=0.6667 val_auc=0.9600 val_acc=0.9513 | alpha_ent=0.0226 rule_corr=0.0346 dead_rules=32 dead_rules_ratio=0.5000 | fuzzy_f1=0.4882 dl_f1=0.7778 | monitor_score=0.5275 | lr=2.28e-04
# 2026-07-09 16:33:11 - Epoch 040/200 | val_f1=0.6812 val_auc=0.9604 val_acc=0.9544 | alpha_ent=0.0228 rule_corr=0.0347 dead_rules=31 dead_rules_ratio=0.4844 | fuzzy_f1=0.4921 dl_f1=0.8063 | monitor_score=0.5387 | lr=2.27e-04
# 2026-07-09 16:33:11 - Epoch 041/200 | val_f1=0.6840 val_auc=0.9606 val_acc=0.9544 | alpha_ent=0.0230 rule_corr=0.0347 dead_rules=31 dead_rules_ratio=0.4844 | fuzzy_f1=0.5000 dl_f1=0.7857 | monitor_score=0.5425 | lr=2.26e-04
# 2026-07-09 16:33:12 - Epoch 042/200 | val_f1=0.6667 val_auc=0.9588 val_acc=0.9513 | alpha_ent=0.0232 rule_corr=0.0346 dead_rules=30 dead_rules_ratio=0.4688 | fuzzy_f1=0.4882 dl_f1=0.7835 | monitor_score=0.5291 | lr=2.25e-04
# 2026-07-09 16:33:13 - Epoch 043/200 | val_f1=0.6726 val_auc=0.9605 val_acc=0.9537 | alpha_ent=0.0233 rule_corr=0.0346 dead_rules=30 dead_rules_ratio=0.4688 | fuzzy_f1=0.5210 dl_f1=0.7917 | monitor_score=0.5411 | lr=2.24e-04
# 2026-07-09 16:33:14 - Epoch 044/200 | val_f1=0.6753 val_auc=0.9627 val_acc=0.9531 | alpha_ent=0.0235 rule_corr=0.0348 dead_rules=29 dead_rules_ratio=0.4531 | fuzzy_f1=0.5161 dl_f1=0.7979 | monitor_score=0.5424 | lr=2.22e-04
# 2026-07-09 16:33:15 - Epoch 045/200 | val_f1=0.6529 val_auc=0.9645 val_acc=0.9475 | alpha_ent=0.0237 rule_corr=0.0348 dead_rules=29 dead_rules_ratio=0.4531 | fuzzy_f1=0.5039 dl_f1=0.8020 | monitor_score=0.5248 | lr=2.21e-04
# 2026-07-09 16:33:16 - Epoch 046/200 | val_f1=0.6638 val_auc=0.9616 val_acc=0.9513 | alpha_ent=0.0239 rule_corr=0.0350 dead_rules=28 dead_rules_ratio=0.4375 | fuzzy_f1=0.5182 dl_f1=0.8125 | monitor_score=0.5362 | lr=2.20e-04
# 2026-07-09 16:33:17 - Epoch 047/200 | val_f1=0.6609 val_auc=0.9593 val_acc=0.9513 | alpha_ent=0.0241 rule_corr=0.0353 dead_rules=27 dead_rules_ratio=0.4219 | fuzzy_f1=0.5161 dl_f1=0.8128 | monitor_score=0.5345 | lr=2.19e-04
# 2026-07-09 16:33:17 - Epoch 048/200 | val_f1=0.6638 val_auc=0.9670 val_acc=0.9513 | alpha_ent=0.0243 rule_corr=0.0357 dead_rules=27 dead_rules_ratio=0.4219 | fuzzy_f1=0.5263 dl_f1=0.8191 | monitor_score=0.5390 | lr=2.17e-04
# 2026-07-09 16:33:18 - Epoch 049/200 | val_f1=0.6638 val_auc=0.9673 val_acc=0.9513 | alpha_ent=0.0245 rule_corr=0.0358 dead_rules=27 dead_rules_ratio=0.4219 | fuzzy_f1=0.5280 dl_f1=0.8235 | monitor_score=0.5394 | lr=2.16e-04
# 2026-07-09 16:33:19 - Epoch 050/200 | val_f1=0.6638 val_auc=0.9647 val_acc=0.9513 | alpha_ent=0.0247 rule_corr=0.0358 dead_rules=26 dead_rules_ratio=0.4062 | fuzzy_f1=0.5039 dl_f1=0.8063 | monitor_score=0.5341 | lr=2.15e-04
# 2026-07-09 16:33:20 - Epoch 051/200 | val_f1=0.6667 val_auc=0.9654 val_acc=0.9500 | alpha_ent=0.0249 rule_corr=0.0360 dead_rules=26 dead_rules_ratio=0.4062 | fuzzy_f1=0.5221 dl_f1=0.8211 | monitor_score=0.5405 | lr=2.13e-04
# 2026-07-09 16:33:21 - Epoch 052/200 | val_f1=0.6752 val_auc=0.9713 val_acc=0.9525 | alpha_ent=0.0251 rule_corr=0.0362 dead_rules=26 dead_rules_ratio=0.4062 | fuzzy_f1=0.5263 dl_f1=0.8254 | monitor_score=0.5471 | lr=2.12e-04
# 2026-07-09 16:33:22 - Epoch 053/200 | val_f1=0.6723 val_auc=0.9710 val_acc=0.9513 | alpha_ent=0.0252 rule_corr=0.0363 dead_rules=26 dead_rules_ratio=0.4062 | fuzzy_f1=0.5255 dl_f1=0.8298 | monitor_score=0.5450 | lr=2.11e-04
# 2026-07-09 16:33:23 - Epoch 054/200 | val_f1=0.6724 val_auc=0.9695 val_acc=0.9525 | alpha_ent=0.0254 rule_corr=0.0364 dead_rules=25 dead_rules_ratio=0.3906 | fuzzy_f1=0.5176 dl_f1=0.8404 | monitor_score=0.5439 | lr=2.09e-04
# 2026-07-09 16:33:23 - Epoch 055/200 | val_f1=0.6900 val_auc=0.9731 val_acc=0.9556 | alpha_ent=0.0256 rule_corr=0.0365 dead_rules=25 dead_rules_ratio=0.3906 | fuzzy_f1=0.5234 dl_f1=0.8191 | monitor_score=0.5567 | lr=2.08e-04
# 2026-07-09 16:33:24 - Epoch 056/200 | val_f1=0.6781 val_auc=0.9752 val_acc=0.9531 | alpha_ent=0.0258 rule_corr=0.0364 dead_rules=25 dead_rules_ratio=0.3906 | fuzzy_f1=0.5317 dl_f1=0.8021 | monitor_score=0.5511 | lr=2.06e-04
# 2026-07-09 16:33:25 - Epoch 057/200 | val_f1=0.6870 val_auc=0.9756 val_acc=0.9550 | alpha_ent=0.0260 rule_corr=0.0365 dead_rules=25 dead_rules_ratio=0.3906 | fuzzy_f1=0.5317 dl_f1=0.8041 | monitor_score=0.5568 | lr=2.05e-04
# 2026-07-09 16:33:26 - Epoch 058/200 | val_f1=0.6812 val_auc=0.9750 val_acc=0.9544 | alpha_ent=0.0262 rule_corr=0.0366 dead_rules=25 dead_rules_ratio=0.3906 | fuzzy_f1=0.5440 dl_f1=0.8021 | monitor_score=0.5561 | lr=2.03e-04
# 2026-07-09 16:33:27 - Epoch 059/200 | val_f1=0.6695 val_auc=0.9719 val_acc=0.9519 | alpha_ent=0.0264 rule_corr=0.0368 dead_rules=25 dead_rules_ratio=0.3906 | fuzzy_f1=0.5339 dl_f1=0.8172 | monitor_score=0.5460 | lr=2.02e-04
# 2026-07-09 16:33:28 - Epoch 060/200 | val_f1=0.6753 val_auc=0.9775 val_acc=0.9531 | alpha_ent=0.0266 rule_corr=0.0370 dead_rules=23 dead_rules_ratio=0.3594 | fuzzy_f1=0.5251 dl_f1=0.8021 | monitor_score=0.5491 | lr=2.00e-04
# 2026-07-09 16:33:28 - Epoch 061/200 | val_f1=0.6695 val_auc=0.9764 val_acc=0.9519 | alpha_ent=0.0268 rule_corr=0.0372 dead_rules=23 dead_rules_ratio=0.3594 | fuzzy_f1=0.5317 dl_f1=0.8191 | monitor_score=0.5470 | lr=1.99e-04
# 2026-07-09 16:33:29 - Epoch 062/200 | val_f1=0.6778 val_auc=0.9768 val_acc=0.9519 | alpha_ent=0.0270 rule_corr=0.0371 dead_rules=23 dead_rules_ratio=0.3594 | fuzzy_f1=0.5276 dl_f1=0.8265 | monitor_score=0.5513 | lr=1.97e-04
# 2026-07-09 16:33:30 - Epoch 063/200 | val_f1=0.6891 val_auc=0.9781 val_acc=0.9537 | alpha_ent=0.0272 rule_corr=0.0372 dead_rules=23 dead_rules_ratio=0.3594 | fuzzy_f1=0.5391 dl_f1=0.8223 | monitor_score=0.5615 | lr=1.96e-04
# 2026-07-09 16:33:31 - Epoch 064/200 | val_f1=0.6894 val_auc=0.9745 val_acc=0.9544 | alpha_ent=0.0273 rule_corr=0.0374 dead_rules=23 dead_rules_ratio=0.3594 | fuzzy_f1=0.5418 dl_f1=0.8316 | monitor_score=0.5623 | lr=1.94e-04
# 2026-07-09 16:33:32 - Epoch 065/200 | val_f1=0.6891 val_auc=0.9796 val_acc=0.9537 | alpha_ent=0.0275 rule_corr=0.0374 dead_rules=23 dead_rules_ratio=0.3594 | fuzzy_f1=0.5292 dl_f1=0.8125 | monitor_score=0.5590 | lr=1.92e-04
# 2026-07-09 16:33:33 - Epoch 066/200 | val_f1=0.6953 val_auc=0.9792 val_acc=0.9556 | alpha_ent=0.0277 rule_corr=0.0375 dead_rules=22 dead_rules_ratio=0.3438 | fuzzy_f1=0.5418 dl_f1=0.8333 | monitor_score=0.5669 | lr=1.91e-04
# 2026-07-09 16:33:34 - Epoch 067/200 | val_f1=0.6894 val_auc=0.9779 val_acc=0.9544 | alpha_ent=0.0279 rule_corr=0.0374 dead_rules=22 dead_rules_ratio=0.3438 | fuzzy_f1=0.5476 dl_f1=0.8247 | monitor_score=0.5645 | lr=1.89e-04
# 2026-07-09 16:33:34 - Epoch 068/200 | val_f1=0.6888 val_auc=0.9808 val_acc=0.9531 | alpha_ent=0.0281 rule_corr=0.0372 dead_rules=22 dead_rules_ratio=0.3438 | fuzzy_f1=0.5455 dl_f1=0.8223 | monitor_score=0.5636 | lr=1.88e-04
# 2026-07-09 16:33:35 - Epoch 069/200 | val_f1=0.6920 val_auc=0.9810 val_acc=0.9544 | alpha_ent=0.0283 rule_corr=0.0372 dead_rules=22 dead_rules_ratio=0.3438 | fuzzy_f1=0.5455 dl_f1=0.8100 | monitor_score=0.5657 | lr=1.86e-04
# 2026-07-09 16:33:36 - Epoch 070/200 | val_f1=0.6971 val_auc=0.9805 val_acc=0.9544 | alpha_ent=0.0285 rule_corr=0.0372 dead_rules=22 dead_rules_ratio=0.3438 | fuzzy_f1=0.5418 dl_f1=0.8141 | monitor_score=0.5681 | lr=1.84e-04
# 2026-07-09 16:33:37 - Epoch 071/200 | val_f1=0.6917 val_auc=0.9818 val_acc=0.9537 | alpha_ent=0.0287 rule_corr=0.0372 dead_rules=22 dead_rules_ratio=0.3438 | fuzzy_f1=0.5412 dl_f1=0.8223 | monitor_score=0.5644 | lr=1.83e-04
# 2026-07-09 16:33:38 - Epoch 072/200 | val_f1=0.7004 val_auc=0.9832 val_acc=0.9556 | alpha_ent=0.0289 rule_corr=0.0374 dead_rules=21 dead_rules_ratio=0.3281 | fuzzy_f1=0.5412 dl_f1=0.8020 | monitor_score=0.5709 | lr=1.81e-04
# 2026-07-09 16:33:38 - Epoch 073/200 | val_f1=0.7124 val_auc=0.9836 val_acc=0.9581 | alpha_ent=0.0290 rule_corr=0.0375 dead_rules=21 dead_rules_ratio=0.3281 | fuzzy_f1=0.5433 dl_f1=0.8182 | monitor_score=0.5792 | lr=1.79e-04
# 2026-07-09 16:33:39 - Epoch 074/200 | val_f1=0.6891 val_auc=0.9824 val_acc=0.9537 | alpha_ent=0.0292 rule_corr=0.0374 dead_rules=21 dead_rules_ratio=0.3281 | fuzzy_f1=0.5370 dl_f1=0.7921 | monitor_score=0.5624 | lr=1.77e-04
# 2026-07-09 16:33:40 - Epoch 075/200 | val_f1=0.6862 val_auc=0.9837 val_acc=0.9531 | alpha_ent=0.0294 rule_corr=0.0374 dead_rules=21 dead_rules_ratio=0.3281 | fuzzy_f1=0.5370 dl_f1=0.8163 | monitor_score=0.5605 | lr=1.76e-04
# 2026-07-09 16:33:41 - Epoch 076/200 | val_f1=0.6750 val_auc=0.9832 val_acc=0.9513 | alpha_ent=0.0296 rule_corr=0.0376 dead_rules=21 dead_rules_ratio=0.3281 | fuzzy_f1=0.5391 dl_f1=0.8223 | monitor_score=0.5538 | lr=1.74e-04
# 2026-07-09 16:33:42 - Epoch 077/200 | val_f1=0.6920 val_auc=0.9840 val_acc=0.9544 | alpha_ent=0.0298 rule_corr=0.0377 dead_rules=21 dead_rules_ratio=0.3281 | fuzzy_f1=0.5391 dl_f1=0.8060 | monitor_score=0.5648 | lr=1.72e-04
# 2026-07-09 16:33:43 - Epoch 078/200 | val_f1=0.7119 val_auc=0.9845 val_acc=0.9575 | alpha_ent=0.0299 rule_corr=0.0379 dead_rules=21 dead_rules_ratio=0.3281 | fuzzy_f1=0.5412 dl_f1=0.8200 | monitor_score=0.5782 | lr=1.70e-04
# 2026-07-09 16:33:43 - Epoch 079/200 | val_f1=0.6942 val_auc=0.9851 val_acc=0.9537 | alpha_ent=0.0301 rule_corr=0.0379 dead_rules=21 dead_rules_ratio=0.3281 | fuzzy_f1=0.5447 dl_f1=0.7961 | monitor_score=0.5676 | lr=1.69e-04
# 2026-07-09 16:33:44 - Epoch 080/200 | val_f1=0.6885 val_auc=0.9841 val_acc=0.9525 | alpha_ent=0.0303 rule_corr=0.0380 dead_rules=22 dead_rules_ratio=0.3438 | fuzzy_f1=0.5469 dl_f1=0.8000 | monitor_score=0.5637 | lr=1.67e-04
# 2026-07-09 16:33:45 - Epoch 081/200 | val_f1=0.6942 val_auc=0.9864 val_acc=0.9537 | alpha_ent=0.0305 rule_corr=0.0381 dead_rules=22 dead_rules_ratio=0.3438 | fuzzy_f1=0.5447 dl_f1=0.8265 | monitor_score=0.5668 | lr=1.65e-04
# 2026-07-09 16:33:46 - Epoch 082/200 | val_f1=0.6833 val_auc=0.9838 val_acc=0.9525 | alpha_ent=0.0307 rule_corr=0.0383 dead_rules=22 dead_rules_ratio=0.3438 | fuzzy_f1=0.5391 dl_f1=0.8040 | monitor_score=0.5583 | lr=1.63e-04
# 2026-07-09 16:33:47 - Epoch 083/200 | val_f1=0.6831 val_auc=0.9849 val_acc=0.9519 | alpha_ent=0.0308 rule_corr=0.0384 dead_rules=22 dead_rules_ratio=0.3438 | fuzzy_f1=0.5391 dl_f1=0.7960 | monitor_score=0.5581 | lr=1.61e-04
# 2026-07-09 16:33:48 - Epoch 084/200 | val_f1=0.6888 val_auc=0.9859 val_acc=0.9531 | alpha_ent=0.0310 rule_corr=0.0386 dead_rules=22 dead_rules_ratio=0.3438 | fuzzy_f1=0.5370 dl_f1=0.7941 | monitor_score=0.5613 | lr=1.59e-04
# 2026-07-09 16:33:49 - Epoch 085/200 | val_f1=0.6971 val_auc=0.9857 val_acc=0.9544 | alpha_ent=0.0312 rule_corr=0.0388 dead_rules=22 dead_rules_ratio=0.3438 | fuzzy_f1=0.5370 dl_f1=0.7923 | monitor_score=0.5667 | lr=1.58e-04
# 2026-07-09 16:33:49 - Epoch 086/200 | val_f1=0.7155 val_auc=0.9863 val_acc=0.9587 | alpha_ent=0.0313 rule_corr=0.0390 dead_rules=21 dead_rules_ratio=0.3281 | fuzzy_f1=0.5397 dl_f1=0.7941 | monitor_score=0.5801 | lr=1.56e-04
# 2026-07-09 16:33:50 - Epoch 087/200 | val_f1=0.7210 val_auc=0.9879 val_acc=0.9594 | alpha_ent=0.0315 rule_corr=0.0393 dead_rules=20 dead_rules_ratio=0.3125 | fuzzy_f1=0.5375 dl_f1=0.8060 | monitor_score=0.5839 | lr=1.54e-04
# 2026-07-09 16:33:51 - Epoch 088/200 | val_f1=0.7173 val_auc=0.9874 val_acc=0.9581 | alpha_ent=0.0317 rule_corr=0.0395 dead_rules=20 dead_rules_ratio=0.3125 | fuzzy_f1=0.5476 dl_f1=0.8100 | monitor_score=0.5840 | lr=1.52e-04
# 2026-07-09 16:33:52 - Epoch 089/200 | val_f1=0.7119 val_auc=0.9875 val_acc=0.9575 | alpha_ent=0.0319 rule_corr=0.0396 dead_rules=20 dead_rules_ratio=0.3125 | fuzzy_f1=0.5512 dl_f1=0.8060 | monitor_score=0.5813 | lr=1.50e-04
# 2026-07-09 16:33:53 - Epoch 090/200 | val_f1=0.7059 val_auc=0.9875 val_acc=0.9563 | alpha_ent=0.0320 rule_corr=0.0396 dead_rules=20 dead_rules_ratio=0.3125 | fuzzy_f1=0.5534 dl_f1=0.8119 | monitor_score=0.5780 | lr=1.48e-04
# 2026-07-09 16:33:53 - Epoch 091/200 | val_f1=0.7009 val_auc=0.9851 val_acc=0.9563 | alpha_ent=0.0322 rule_corr=0.0397 dead_rules=20 dead_rules_ratio=0.3125 | fuzzy_f1=0.5512 dl_f1=0.7960 | monitor_score=0.5741 | lr=1.46e-04
# 2026-07-09 16:33:54 - Epoch 092/200 | val_f1=0.7273 val_auc=0.9882 val_acc=0.9606 | alpha_ent=0.0323 rule_corr=0.0399 dead_rules=19 dead_rules_ratio=0.2969 | fuzzy_f1=0.5490 dl_f1=0.7921 | monitor_score=0.5915 | lr=1.45e-04
# 2026-07-09 16:33:55 - Epoch 093/200 | val_f1=0.7064 val_auc=0.9885 val_acc=0.9569 | alpha_ent=0.0325 rule_corr=0.0399 dead_rules=19 dead_rules_ratio=0.2969 | fuzzy_f1=0.5512 dl_f1=0.7980 | monitor_score=0.5785 | lr=1.43e-04
# 2026-07-09 16:33:56 - Epoch 094/200 | val_f1=0.7281 val_auc=0.9892 val_acc=0.9613 | alpha_ent=0.0327 rule_corr=0.0400 dead_rules=19 dead_rules_ratio=0.2969 | fuzzy_f1=0.5534 dl_f1=0.7980 | monitor_score=0.5931 | lr=1.41e-04
# 2026-07-09 16:33:57 - Epoch 095/200 | val_f1=0.7304 val_auc=0.9897 val_acc=0.9613 | alpha_ent=0.0328 rule_corr=0.0402 dead_rules=18 dead_rules_ratio=0.2812 | fuzzy_f1=0.5534 dl_f1=0.8058 | monitor_score=0.5954 | lr=1.39e-04
# 2026-07-09 16:33:58 - Epoch 096/200 | val_f1=0.7434 val_auc=0.9904 val_acc=0.9637 | alpha_ent=0.0330 rule_corr=0.0403 dead_rules=18 dead_rules_ratio=0.2812 | fuzzy_f1=0.5534 dl_f1=0.8177 | monitor_score=0.6038 | lr=1.37e-04
# 2026-07-09 16:33:58 - Epoch 097/200 | val_f1=0.7241 val_auc=0.9892 val_acc=0.9600 | alpha_ent=0.0332 rule_corr=0.0404 dead_rules=18 dead_rules_ratio=0.2812 | fuzzy_f1=0.5569 dl_f1=0.7923 | monitor_score=0.5922 | lr=1.35e-04
# 2026-07-09 16:33:59 - Epoch 098/200 | val_f1=0.7193 val_auc=0.9886 val_acc=0.9600 | alpha_ent=0.0333 rule_corr=0.0405 dead_rules=18 dead_rules_ratio=0.2812 | fuzzy_f1=0.5512 dl_f1=0.7843 | monitor_score=0.5876 | lr=1.33e-04
# 2026-07-09 16:34:00 - Epoch 099/200 | val_f1=0.6939 val_auc=0.9876 val_acc=0.9531 | alpha_ent=0.0335 rule_corr=0.0406 dead_rules=18 dead_rules_ratio=0.2812 | fuzzy_f1=0.5534 dl_f1=0.7793 | monitor_score=0.5716 | lr=1.31e-04
# 2026-07-09 16:34:01 - Epoch 100/200 | val_f1=0.7200 val_auc=0.9888 val_acc=0.9606 | alpha_ent=0.0336 rule_corr=0.0408 dead_rules=18 dead_rules_ratio=0.2812 | fuzzy_f1=0.5534 dl_f1=0.7960 | monitor_score=0.5886 | lr=1.29e-04
# 2026-07-09 16:34:02 - Epoch 101/200 | val_f1=0.6883 val_auc=0.9880 val_acc=0.9519 | alpha_ent=0.0338 rule_corr=0.0409 dead_rules=18 dead_rules_ratio=0.2812 | fuzzy_f1=0.5512 dl_f1=0.8019 | monitor_score=0.5674 | lr=1.28e-04
# 2026-07-09 16:34:03 - Epoch 102/200 | val_f1=0.6975 val_auc=0.9891 val_acc=0.9550 | alpha_ent=0.0339 rule_corr=0.0411 dead_rules=19 dead_rules_ratio=0.2969 | fuzzy_f1=0.5625 dl_f1=0.7885 | monitor_score=0.5754 | lr=1.26e-04
# 2026-07-09 16:34:03 - Epoch 103/200 | val_f1=0.7069 val_auc=0.9887 val_acc=0.9575 | alpha_ent=0.0341 rule_corr=0.0413 dead_rules=19 dead_rules_ratio=0.2969 | fuzzy_f1=0.5692 dl_f1=0.7826 | monitor_score=0.5832 | lr=1.24e-04
# 2026-07-09 16:34:04 - Epoch 104/200 | val_f1=0.7124 val_auc=0.9882 val_acc=0.9581 | alpha_ent=0.0342 rule_corr=0.0414 dead_rules=19 dead_rules_ratio=0.2969 | fuzzy_f1=0.5703 dl_f1=0.7864 | monitor_score=0.5870 | lr=1.22e-04
# 2026-07-09 16:34:05 - Epoch 105/200 | val_f1=0.6920 val_auc=0.9882 val_acc=0.9544 | alpha_ent=0.0344 rule_corr=0.0415 dead_rules=19 dead_rules_ratio=0.2969 | fuzzy_f1=0.5657 dl_f1=0.7961 | monitor_score=0.5726 | lr=1.20e-04
# 2026-07-09 16:34:06 - Epoch 106/200 | val_f1=0.6971 val_auc=0.9880 val_acc=0.9544 | alpha_ent=0.0345 rule_corr=0.0417 dead_rules=20 dead_rules_ratio=0.3125 | fuzzy_f1=0.5714 dl_f1=0.7887 | monitor_score=0.5765 | lr=1.18e-04
# 2026-07-09 16:34:07 - Epoch 107/200 | val_f1=0.6979 val_auc=0.9888 val_acc=0.9556 | alpha_ent=0.0346 rule_corr=0.0417 dead_rules=20 dead_rules_ratio=0.3125 | fuzzy_f1=0.5692 dl_f1=0.7961 | monitor_score=0.5765 | lr=1.16e-04
# 2026-07-09 16:34:08 - Epoch 108/200 | val_f1=0.7029 val_auc=0.9882 val_acc=0.9556 | alpha_ent=0.0348 rule_corr=0.0419 dead_rules=20 dead_rules_ratio=0.3125 | fuzzy_f1=0.5703 dl_f1=0.7962 | monitor_score=0.5800 | lr=1.14e-04
# ...
# 2026-07-09 19:42:08 - Epoch 155/200 | val_f1=0.9291 val_auc=0.9924 val_acc=0.9925 | alpha_ent=0.3615 rule_corr=0.0885 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.6405 dl_f1=0.8976 | monitor_score=0.7416 | lr=1.58e-04
# 2026-07-09 19:42:09 - Epoch 156/200 | val_f1=0.9291 val_auc=0.9925 val_acc=0.9925 | alpha_ent=0.3617 rule_corr=0.0884 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.6405 dl_f1=0.8769 | monitor_score=0.7416 | lr=1.51e-04
# 2026-07-09 19:42:10 - Epoch 157/200 | val_f1=0.9291 val_auc=0.9929 val_acc=0.9925 | alpha_ent=0.3619 rule_corr=0.0884 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.6405 dl_f1=0.9048 | monitor_score=0.7416 | lr=1.45e-04
# 2026-07-09 19:42:11 - Epoch 158/200 | val_f1=0.9291 val_auc=0.9927 val_acc=0.9925 | alpha_ent=0.3621 rule_corr=0.0884 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.6405 dl_f1=0.8837 | monitor_score=0.7415 | lr=1.39e-04
# 2026-07-09 19:42:12 - Epoch 159/200 | val_f1=0.9291 val_auc=0.9930 val_acc=0.9925 | alpha_ent=0.3623 rule_corr=0.0884 dead_rules=0 dead_rules_ratio=0.0000 | fuzzy_f1=0.6405 dl_f1=0.9219 | monitor_score=0.7415 | lr=1.33e-04
# 2026-07-09 19:42:12 - Early stopping en epoch 159 (patience=30).
# [I 2026-07-09 19:42:12,919] Trial 79 finished with value: 0.7482405250655706 and parameters: {'sequence_length': 180, 'solapamiento_beta': 0.0, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.15000000000000002, 'bidirectional': True, 'embedding_dim': 32, 'n_mf': 3, 'n_rules': 48, 'temperature': 0.9, 't_norm': 'product', 'normalize_rules': True, 'init_alpha': 'sparse', 'lambda_anomaly': 0.75, 'batch_size': 128, 'lr_rate': 0.00125, 'scheduler_type': 'cosine', 'anomaly_weight': 1.8, 'aux_anom_dl_weight': 0.4, 'aux_anom_fuzzy_weight': 1.15, 'diversity_weight': 0.02, 'alpha_entropy_weight': 0.015, 'rule_structure_div_weight': 0.01, 'rule_usage_balance_weight': 0.05}. Best is trial 75 with value: 0.7848015293060463.
# Mejor trial: 75
# Mejor score: 0.784802
#
# === Mejores hiperparámetros optimizados ===
# {
#   "sequence_length": 180,
#   "solapamiento_beta": 0.5,
#   "hidden_size": 32,
#   "num_layers": 2,
#   "dropout": 0.30000000000000004,
#   "bidirectional": true,
#   "embedding_dim": 32,
#   "n_mf": 5,
#   "n_rules": 24,
#   "temperature": 0.8,
#   "t_norm": "product",
#   "normalize_rules": true,
#   "init_alpha": "sparse",
#   "lambda_anomaly": 0.7,
#   "batch_size": 256,
#   "lr_rate": 0.00175,
#   "scheduler_type": "cosine",
#   "anomaly_weight": 2.0,
#   "aux_anom_dl_weight": 0.4,
#   "aux_anom_fuzzy_weight": 0.95,
#   "diversity_weight": 0.005,
#   "alpha_entropy_weight": 0.01,
#   "rule_structure_div_weight": 0.02,
#   "rule_usage_balance_weight": 0.04
# }
#
# Modelo Optuna guardado en: ../models/artifacts/best_optuna_model.pt
# Mejor trial guardado en: ../models/metrics/best_optuna_results.json
# Carpeta temporal '../models/artifacts/temp_optuna_trials' eliminada con éxito.
#
# === Top 10 trials ===
#     number     value     state  params_alpha_entropy_weight  \
# 75      75  0.784802  COMPLETE                        0.010
# 59      59  0.782608  COMPLETE                        0.015
# 68      68  0.782210  COMPLETE                        0.010
# 42      42  0.776851  COMPLETE                        0.010
# 44      44  0.775161  COMPLETE                        0.005
# 50      50  0.771463  COMPLETE                        0.005
# 69      69  0.770493  COMPLETE                        0.010
# 46      46  0.769284  COMPLETE                        0.010
# 45      45  0.769078  COMPLETE                        0.005
# 43      43  0.768967  COMPLETE                        0.005
#
#     params_anomaly_weight  params_aux_anom_dl_weight  \
# 75                    2.0                       0.40
# 59                    2.0                       0.45
# 68                    1.9                       0.40
# 42                    2.1                       0.35
# 44                    2.1                       0.35
# 50                    2.2                       0.40
# 69                    1.8                       0.35
# 46                    2.1                       0.35
# 45                    2.2                       0.30
# 43                    2.3                       0.30
#
#     params_aux_anom_fuzzy_weight  params_batch_size  params_bidirectional  \
# 75                          0.95                256                  True
# 59                          1.00                256                  True
# 68                          1.15                256                  True
# 42                          0.85                256                  True
# 44                          0.85                256                  True
# 50                          0.80                256                  True
# 69                          1.15                256                  True
# 46                          1.05                256                  True
# 45                          0.95                256                  True
# 43                          0.90                256                  True
#
#     params_diversity_weight  params_dropout  params_embedding_dim  \
# 75                    0.005            0.30                    32
# 59                    0.010            0.20                    32
# 68                    0.015            0.10                    32
# 42                    0.015            0.25                    48
# 44                    0.020            0.30                    48
# 50                    0.020            0.30                    32
# 69                    0.020            0.10                    32
# 46                    0.020            0.25                    48
# 45                    0.020            0.25                    48
# 43                    0.020            0.25                    48
#
#     params_hidden_size params_init_alpha  params_lambda_anomaly  \
# 75                  32            sparse                   0.70
# 59                 128            sparse                   0.70
# 68                 128            sparse                   0.70
# 42                  32            sparse                   0.70
# 44                  32            sparse                   0.75
# 50                 128            sparse                   0.70
# 69                 128            sparse                   0.70
# 46                  32            sparse                   0.75
# 45                  32            sparse                   0.80
# 43                  32            sparse                   0.75
#
#     params_lr_rate  params_n_mf  params_n_rules  params_normalize_rules  \
# 75         0.00175            5              24                    True
# 59         0.00175            5              64                    True
# 68         0.00175            5              48                    True
# 42         0.00150            5              24                    True
# 44         0.00175            5              24                    True
# 50         0.00125            5              24                    True
# 69         0.00125            5              48                    True
# 46         0.00075            5              24                    True
# 45         0.00125            5              24                    True
# 43         0.00150            5              24                    True
#
#     params_num_layers  params_rule_structure_div_weight  \
# 75                  2                              0.02
# 59                  2                              0.03
# 68                  2                              0.02
# 42                  2                              0.02
# 44                  2                              0.03
# 50                  2                              0.05
# 69                  2                              0.01
# 46                  2                              0.02
# 45                  2                              0.04
# 43                  2                              0.03
#
#     params_rule_usage_balance_weight params_scheduler_type  \
# 75                              0.04                cosine
# 59                              0.04                cosine
# 68                              0.04                cosine
# 42                              0.04                cosine
# 44                              0.01                cosine
# 50                              0.01                cosine
# 69                              0.05                cosine
# 46                              0.02                cosine
# 45                              0.01                cosine
# 43                              0.01                cosine
#
#     params_sequence_length  params_solapamiento_beta params_t_norm  \
# 75                     180                       0.5       product
# 59                     180                       0.5       product
# 68                     180                       0.5       product
# 42                     180                       0.5       product
# 44                     180                       0.5       product
# 50                     180                       0.5       product
# 69                     180                       0.5       product
# 46                     180                       0.5       product
# 45                     180                       0.5       product
# 43                     180                       0.5       product
#
#     params_temperature  user_attrs_alpha_entropy_mean  user_attrs_best_epoch  \
# 75                0.80                       0.412066                    133
# 59                0.70                       0.424731                    111
# 68                0.80                       0.486943                    154
# 42                0.70                       0.306317                    118
# 44                0.70                       0.279502                     91
# 50                0.85                       0.343810                    103
# 69                0.95                       0.519760                    148
# 46                0.70                       0.140525                     96
# 45                0.70                       0.276636                    137
# 43                0.65                       0.262258                    105
#
#                             user_attrs_best_meta_path  \
# 75  ../models/artifacts/temp_optuna_trials\temp_be...
# 59  ../models/artifacts/temp_optuna_trials\temp_be...
# 68                                                NaN
# 42  ../models/artifacts/temp_optuna_trials\temp_be...
# 44                                                NaN
# 50                                                NaN
# 69                                                NaN
# 46                                                NaN
# 45                                                NaN
# 43                                                NaN
#
#     user_attrs_best_threshold  \
# 75                       0.41
# 59                       0.50
# 68                       0.36
# 42                       0.57
# 44                       0.54
# 50                       0.36
# 69                       0.67
# 46                       0.36
# 45                       0.63
# 43                       0.53
#
#                                user_attrs_bundle_dir  \
# 75  ../models/artifacts/temp_optuna_trials\temp_best
# 59  ../models/artifacts/temp_optuna_trials\temp_best
# 68                                               NaN
# 42  ../models/artifacts/temp_optuna_trials\temp_best
# 44                                               NaN
# 50                                               NaN
# 69                                               NaN
# 46                                               NaN
# 45                                               NaN
# 43                                               NaN
#
#                            user_attrs_checkpoint_path  user_attrs_dead_rules  \
# 75  ../models/artifacts/temp_optuna_trials\best_op...                      0
# 59  ../models/artifacts/temp_optuna_trials\best_op...                      0
# 68  ../models/artifacts/temp_optuna_trials\best_op...                      1
# 42  ../models/artifacts/temp_optuna_trials\best_op...                      0
# 44  ../models/artifacts/temp_optuna_trials\best_op...                      0
# 50  ../models/artifacts/temp_optuna_trials\best_op...                      0
# 69  ../models/artifacts/temp_optuna_trials\best_op...                      0
# 46  ../models/artifacts/temp_optuna_trials\best_op...                      0
# 45  ../models/artifacts/temp_optuna_trials\best_op...                      0
# 43  ../models/artifacts/temp_optuna_trials\best_op...                      0
#
#     user_attrs_dl_f1  user_attrs_fuzzy_f1  user_attrs_n_epochs_trained  \
# 75          0.932203             0.775087                          163
# 59          0.923077             0.787879                          141
# 68          0.928870             0.790698                          184
# 42          0.938272             0.709898                          148
# 44          0.935065             0.755396                          121
# 50          0.923729             0.717770                          133
# 69          0.932773             0.773946                          178
# 46          0.902954             0.700680                          126
# 45          0.923077             0.722222                          167
# 43          0.937238             0.733813                          135
#
#     user_attrs_rule_corr_mean  user_attrs_score  user_attrs_val_anomaly_auc  \
# 75                   0.071863          0.784802                    0.998333
# 59                   0.053373          0.782608                    0.997533
# 68                   0.055607          0.782210                    0.997851
# 42                   0.061515          0.776851                    0.998254
# 44                   0.061766          0.775161                    0.997515
# 50                   0.063708          0.771463                    0.993622
# 69                   0.066158          0.770493                    0.998144
# 46                   0.060190          0.769284                    0.995712
# 45                   0.058188          0.769078                    0.999032
# 43                   0.060529          0.768967                    0.997537
#
#     user_attrs_val_anomaly_f1
# 75                   0.946502
# 59                   0.937759
# 68                   0.942623
# 42                   0.950413
# 44                   0.928270
# 50                   0.942149
# 69                   0.932773
# 46                   0.929461
# 45                   0.931174
# 43                   0.925620
#
# === Importancia de hiperparámetros ===
# {
#   "normalize_rules": 0.7260618796349859,
#   "num_layers": 0.0618028028267098,
#   "aux_anom_dl_weight": 0.045418210310346235,
#   "temperature": 0.0266784380729649,
#   "diversity_weight": 0.022302350874782627,
#   "dropout": 0.015720104018378322,
#   "n_rules": 0.012159768283549427,
#   "anomaly_weight": 0.009153881096014319,
#   "solapamiento_beta": 0.007795716623441552,
#   "lr_rate": 0.007601373259187563,
#   "hidden_size": 0.007360382691128185,
#   "rule_usage_balance_weight": 0.0071256976613594866,
#   "embedding_dim": 0.006837732740973576,
#   "bidirectional": 0.006627239737263802,
#   "aux_anom_fuzzy_weight": 0.006538187073532968,
#   "scheduler_type": 0.005115351036683772,
#   "n_mf": 0.004893808779201052,
#   "lambda_anomaly": 0.004888299947172105,
#   "t_norm": 0.004243030390441632,
#   "batch_size": 0.0034216769667293127,
#   "rule_structure_div_weight": 0.002587785286803864,
#   "alpha_entropy_weight": 0.002109760891007607,
#   "sequence_length": 0.0018535726154882174,
#   "init_alpha": 0.0017029491818540308
# }
